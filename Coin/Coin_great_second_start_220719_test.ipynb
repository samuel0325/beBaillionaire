# %%
pip install pyupbit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.2/97.2 kB 3.0 MB/s eta 0:00:00
# ...
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyupbit
print(pyupbit.Upbit)
# Out:
# <class 'pyupbit.exchange_api.Upbit'>

# %%
df = pyupbit.get_ohlcv("KRW-BTC", count=1)

# %%
time.strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-09-22 22:54:33'

# %%
df['close'][0]
# Out:
# 26944000.0

# %%
ticker = binance.fetch_ticker('BTC/USDT')
print(ticker['open'], ticker['high'], ticker['low'], ticker['close'])
# Out:
# 19268.46 19956.0 18125.98 18963.29

# %%
df['open'][0]
# Out:
# 26523000.0

# %%
df
# Out:
#                            open        high         low       close  \
# 2022-09-22 09:00:00  26523000.0  27492000.0  26478000.0  26950000.0
#
#                           volume         value
# 2022-09-22 09:00:00  3990.425949  1.077868e+11

# %%
df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'value'], dtype='object')

# %%
pip install urllib3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
tickers = pyupbit.get_tickers()

# %%
print(tickers)
# Out:
# ['KRW-BTC', 'KRW-ETH', 'BTC-ETH', 'BTC-XRP', 'BTC-ETC', 'BTC-OMG', 'BTC-CVC', 'BTC-DGB', 'BTC-SC', 'BTC-SNT', 'BTC-WAVES', 'BTC-NMR', 'BTC-XEM', 'BTC-QTUM', 'BTC-BAT', 'BTC-LSK', 'BTC-STEEM', 'BTC-DOGE', 'BTC-BNT', 'BTC-XLM', 'BTC-ARDR', 'BTC-ARK', 'BTC-STORJ', 'BTC-GRS', 'BTC-REP', 'BTC-RLC', 'USDT-BTC', 'USDT-ETH', 'USDT-XRP', 'USDT-ETC', 'KRW-NEO', 'KRW-MTL', 'KRW-XRP', 'KRW-ETC', 'KRW-OMG', 'KRW-SNT', 'KRW-WAVES', 'KRW-XEM', 'KRW-QTUM', 'KRW-LSK', 'KRW-STEEM', 'KRW-XLM', 'KRW-ARDR', 'KRW-ARK', 'KRW-STORJ', 'KRW-GRS', 'KRW-REP', 'KRW-ADA', 'BTC-ADA', 'BTC-MANA', 'USDT-OMG', 'KRW-SBD', 'BTC-SBD', 'KRW-POWR', 'BTC-POWR', 'KRW-BTG', 'USDT-ADA', 'BTC-DNT', 'BTC-ZRX', 'BTC-TRX', 'BTC-TUSD', 'BTC-LRC', 'KRW-ICX', 'KRW-EOS', 'USDT-TUSD', 'KRW-TRX', 'BTC-POLY', 'USDT-SC', 'USDT-TRX', 'KRW-SC', 'KRW-ONT', 'KRW-ZIL', 'KRW-POLY', 'KRW-ZRX', 'KRW-LOOM', 'BTC-BCH', 'USDT-BCH', 'KRW-BCH', 'BTC-MFT', 'BTC-LOOM', 'KRW-BAT', 'KRW-IOST', 'BTC-RFR', 'KRW-RFR', 'USDT-DGB', 'KRW-CVC', 'KRW-IQ', 'KRW-I
# ...

# %%
tickers = pyupbit.get_tickers(fiat="KRW")
print(tickers)
# Out:
# ['KRW-BTC', 'KRW-ETH', 'KRW-NEO', 'KRW-MTL', 'KRW-XRP', 'KRW-ETC', 'KRW-OMG', 'KRW-SNT', 'KRW-WAVES', 'KRW-XEM', 'KRW-QTUM', 'KRW-LSK', 'KRW-STEEM', 'KRW-XLM', 'KRW-ARDR', 'KRW-ARK', 'KRW-STORJ', 'KRW-GRS', 'KRW-REP', 'KRW-ADA', 'KRW-SBD', 'KRW-POWR', 'KRW-BTG', 'KRW-ICX', 'KRW-EOS', 'KRW-TRX', 'KRW-SC', 'KRW-ONT', 'KRW-ZIL', 'KRW-POLY', 'KRW-ZRX', 'KRW-LOOM', 'KRW-BCH', 'KRW-BAT', 'KRW-IOST', 'KRW-RFR', 'KRW-CVC', 'KRW-IQ', 'KRW-IOTA', 'KRW-MFT', 'KRW-ONG', 'KRW-GAS', 'KRW-UPP', 'KRW-ELF', 'KRW-KNC', 'KRW-BSV', 'KRW-THETA', 'KRW-QKC', 'KRW-BTT', 'KRW-MOC', 'KRW-ENJ', 'KRW-TFUEL', 'KRW-MANA', 'KRW-ANKR', 'KRW-AERGO', 'KRW-ATOM', 'KRW-TT', 'KRW-CRE', 'KRW-MBL', 'KRW-WAXP', 'KRW-HBAR', 'KRW-MED', 'KRW-MLK', 'KRW-STPT', 'KRW-ORBS', 'KRW-VET', 'KRW-CHZ', 'KRW-STMX', 'KRW-DKA', 'KRW-HIVE', 'KRW-KAVA', 'KRW-AHT', 'KRW-LINK', 'KRW-XTZ', 'KRW-BORA', 'KRW-JST', 'KRW-CRO', 'KRW-TON', 'KRW-SXP', 'KRW-HUNT', 'KRW-PLA', 'KRW-DOT', 'KRW-SRM', 'KRW-MVL', 'KRW-STRAX', 'KRW-AQT', 'KRW-GLM', 'KRW-SSX'
# ...

# %%
# !brew install ta-lib
# Out:
# Running `brew update --auto-update`...
# ==> Homebrew is run entirely by unpaid volunteers. Please consider donating:
#   https://github.com/Homebrew/brew#donations
#
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/services).
# ==> New Formulae
# adamstark-audiofile        leapp-cli                  phrase-cli
# astro                      levant                     pipe-rename
# aws2-wrap                  lexicon                    pixie
# aztfy                      lgeneral                   pixiewps
# bfgminer                   libbpf                     poac
# cargo-bundle               libnetfilter_conntrack     pocl
# cargo-nextest              libnftnl                   podman-compose
# cargo-udeps                libnl                      protobuf@3
# circumflex                 libobjc2                   python-build
# czg                        libpython-tabulate         qbe
# dart-sdk                   licensor                   qsv
# ...

# %%
# !pip install TA-Lib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.4/269.4 kB 2.7 MB/s eta 0:00:00m eta 0:00:010:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for TA-Lib: filename=TA_Lib-0.4.24-cp37-cp37m-macosx_10_9_x86_64.whl size=435572 sha256=76dba8bce3683e91ef50284697c7f7f529a24a1cecb3c67d37817ac0f209c372
#   Stored in directory: /Users/kangsung-gon/Library/Caches/pip/wheels/02/b1/a5/aca31e8cdd0137d7a83bf72237056b8705663dd1f9b5eac11e
# Successfully built TA-Lib
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import talib as ta
import pyupbit
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ticker = "KRW-ETH"
df = pyupbit.get_ohlcv(ticker, interval = 'minute60', count=44400)
df.head()
# Out:
#                          open      high       low     close       volume  \
# 2017-09-25 12:00:00  324500.0  325500.0  320000.0  322500.0  1303.032290
# 2017-09-25 13:00:00  322500.0  324000.0  322000.0  322500.0   118.801837
# 2017-09-25 22:00:00  323000.0  323000.0  321000.0  321000.0     0.002000
# 2017-09-25 23:00:00  321000.0  324000.0  321000.0  324000.0     0.002200
# 2017-09-26 00:00:00  323000.0  324500.0  321500.0  323500.0     0.001500
#
#                             value
# 2017-09-25 12:00:00  4.206360e+08
# 2017-09-25 13:00:00  3.836718e+07
# 2017-09-25 22:00:00  6.444500e+02
# 2017-09-25 23:00:00  7.091500e+02
# 2017-09-26 00:00:00  4.843500e+02

# %%
upbit_eth_price = pyupbit.get_current_price("KRW-BTC")
print(upbit_eth_price)
# Out:
# 26875000.0

# %%
# !pip install ccxt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 6.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.3 MB/s eta 0:00:007.2 MB/s eta 0:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.2/75.2 kB 3.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.8.1
#     Uninstalling yarl-1.8.1:
#       Successfully uninstalled yarl-1.8.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 49.2.0.post20200714
#     Uninstalling setuptools-49.2.0.post20200714:
#       Successfully uninstalled setuptools-49.2.0.post20200714
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import ccxt
binance = ccxt.binance()

# %%
markets = binance.fetch_tickers()
print(markets.keys())
# Out:
# dict_keys(['ETH/BTC', 'LTC/BTC', 'BNB/BTC', 'NEO/BTC', 'QTUM/ETH', 'EOS/ETH', 'SNT/ETH', 'BNT/ETH', 'BCC/BTC', 'GAS/BTC', 'BNB/ETH', 'BTC/USDT', 'ETH/USDT', 'HSR/BTC', 'OAX/ETH', 'DNT/ETH', 'MCO/ETH', 'ICN/ETH', 'MCO/BTC', 'WTC/BTC', 'WTC/ETH', 'LRC/BTC', 'LRC/ETH', 'QTUM/BTC', 'YOYOW/BTC', 'OMG/BTC', 'OMG/ETH', 'ZRX/BTC', 'ZRX/ETH', 'STRAT/BTC', 'STRAT/ETH', 'SNGLS/BTC', 'SNGLS/ETH', 'BQX/BTC', 'BQX/ETH', 'KNC/BTC', 'KNC/ETH', 'FUN/BTC', 'FUN/ETH', 'SNM/BTC', 'SNM/ETH', 'NEO/ETH', 'IOTA/BTC', 'IOTA/ETH', 'LINK/BTC', 'LINK/ETH', 'XVG/BTC', 'XVG/ETH', 'SALT/BTC', 'SALT/ETH', 'MDA/BTC', 'MDA/ETH', 'MTL/BTC', 'MTL/ETH', 'SUB/BTC', 'SUB/ETH', 'EOS/BTC', 'SNT/BTC', 'ETC/ETH', 'ETC/BTC', 'MTH/BTC', 'MTH/ETH', 'ENG/BTC', 'ENG/ETH', 'DNT/BTC', 'ZEC/BTC', 'ZEC/ETH', 'BNT/BTC', 'AST/BTC', 'AST/ETH', 'DASH/BTC', 'DASH/ETH', 'OAX/BTC', 'ICN/BTC', 'BTG/BTC', 'BTG/ETH', 'EVX/BTC', 'EVX/ETH', 'REQ/BTC', 'REQ/ETH', 'VIB/BTC', 'VIB/ETH', 'HSR/ETH', 'TRX/BTC', 'TRX/ETH', 'POWR/BTC', 'POWR/ETH', 'ARK/B
# ...

# %%
core_usdt = []
for i in markets.keys():
    now_core = i.split("/")[1]
    now_currrency = i.split("/")[0]
    if now_core == 'USDT':
        core_usdt.append(now_currrency)

# %%
pyupbit.get_current_price("KRW-T")
# Out:
# 43.0

# %%
import time

# %%
core_usdt_binance
# Out:
# ['BTC',
#  'ETH',
#  'BNB',
#  'BCC',
#  'NEO',
#  'LTC',
#  'QTUM',
#  'ADA',
#  'XRP',
#  'EOS',
#  'TUSD',
#  'IOTA',
#  'XLM',
#  'ONT',
#  'TRX',
#  'ETC',
#  'ICX',
#  'VEN',
#  'NULS',
#  'VET',
#  'PAX',
#  'BCH',
#  'BSV',
#  'USDC',
#  'LINK',
#  'WAVES',
#  'BTT',
#  'USDS',
#  'ONG',
#  'HOT',
#  'ZIL',
#  'ZRX',
#  'FET',
#  'BAT',
#  'XMR',
#  'ZEC',
#  'IOST',
#  'CELR',
#  'DASH',
#  'NANO',
#  'OMG',
#  'THETA',
#  'ENJ',
#  'MITH',
#  'MATIC',
#  'ATOM',
#  'TFUEL',
#  'ONE',
#  'FTM',
#  'ALGO',
#  'USDSB',
#  'GTO',
#  'ERD',
#  'DOGE',
#  'DUSK',
#  'ANKR',
#  'WIN',
#  'COS',
#  'NPXS',
#  'COCOS',
#  'MTL',
#  'TOMO',
#  'PERL',
#  'DENT',
#  'MFT',
#  'KEY',
#  'STORM',
#  'DOCK',
#  'WAN',
#  'FUN',
#  'CVC',
#  'CHZ',
#  'BAND',
#  'BUSD',
#  'BEAM',
#  'XTZ',
#  'REN',
#  'RVN',
#  'HC',
#  'HBAR',
#  'NKN',
#  'STX',
#  'KAVA',
#  'ARPA',
#  'IOTX',
#  'RLC',
#  'MCO',
#  'CTXC',
#  'TROY',
#  'VITE',
#  'FTT',
#  'EUR',
#  'OGN',
#  'DREP',
#  'BULL',
# ...

# %%
upbit_binance_tickers = []
for i in core_usdt_binance:
    if i in core_krw_upbit:
        upbit_binance_tickers.append(i)

# %%
# !pip install finance-datareader
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
# !pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 1.0 MB/s eta 0:00:000:00:01
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import yfinance as yf

# %%
USDKRW = yf.Ticker("USDKRW=X")

# %%
USDKRW.info.get('regularMarketPrice')
# Out:
# 1396.04

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/mk/vvw0fvgs2n9947bdh48x53xh0000gn/T/ipykernel_94836/1554875631.py in <module>
# ----> 1 yf.get_live_price()
#
# AttributeError: module 'yfinance' has no attribute 'get_live_price'

# %%
print(len(upbit_binance_tickers))
print(len(core_krw_upbit))
print(len(core_usdt_binance))
# Out:
# 79
# 113
# 408

# %%
print("문자열 변환 : ", time.strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 문자열 변환 :  2022-09-21 16:12:23

# %%
def now_kimchi():
    print("현재 시간 :", time.strftime('%Y-%m-%d %H:%M:%S'))
    USDKRW = yf.Ticker("USDKRW=X")
    now_usd_krw = USDKRW.info.get('regularMarketPrice')
    print('현재 $1 가격 : ₩',now_usd_krw)
    for i in upbit_binance_tickers:
        time.sleep(0.05)
        now_upbit_price = pyupbit.get_current_price("KRW-"+i)
        now_binance_price = binance.fetch_ticker(i+'/USDT')['close']
        if now_binance_price == 0:
            continue
        print('ticker : '+i)
        print("$",now_binance_price)
        print("₩",now_upbit_price)
        print(round((now_upbit_price*100/(now_binance_price*now_usd_krw))-100,3),"%")
        print('-------------------')

# %%
now_kimchi()
# Out:
# 현재 시간 : 2022-09-21 16:31:16
# 현재 $1 가격 : ₩ 1396.05
# ticker : BTC
# $ 18926.6
# ₩ 26814000.0
# 1.482 %
# -------------------
# ticker : ETH
# $ 1328.71
# ₩ 1883500.0
# 1.539 %
# -------------------
# ticker : NEO
# $ 8.23
# ₩ 11700.0
# 1.832 %
# -------------------
# ticker : QTUM
# $ 2.818
# ₩ 3995.0
# 1.549 %
# -------------------
# ticker : ADA
# $ 0.4457
# ₩ 632.0
# 1.572 %
# -------------------
# ticker : XRP
# $ 0.3951
# ₩ 560.0
# 1.527 %
# -------------------
# ticker : EOS
# $ 1.291
# ₩ 1830.0
# 1.537 %
# -------------------
# ticker : IOTA
# $ 0.2566
# ₩ 364.0
# 1.612 %
# -------------------
# ticker : XLM
# $ 0.1129
# ₩ 160.0
# 1.514 %
# -------------------
# ticker : ONT
# $ 0.2161
# ₩ 307.0
# 1.761 %
# -------------------
# ticker : TRX
# $ 0.05948
# ₩ 84.4
# 1.641 %
# -------------------
# ticker : ETC
# $ 28.39
# ₩ 40300.0
# 1.681 %
# -------------------
# ticker : ICX
# $ 0.2357
# ₩ 335.0
# 1.809 %
# -------------------
# ticker : VET
# $ 0.02219
# ₩ 31.5
# 1.684 %
# ...

# %%
for i in krw_btc_price

# %%
usdt_btc_price = pyupbit.get_current_price("USDT-BTC")
krw_btc_price = pyupbit.get_current_price("KRW-BTC")

# %%
krw_btc_price
# Out:
# 26745000.0

# %%
now_btc_kimchi/1396.85
# Out:
# 1.0111285093646665

# %%
1418.571526383598/1396.85
# Out:
# 1.0155503643079773

# %%
now_btc_kimchi
# Out:
# 1418.571526383598

# %%
now_btc_kimchi = krw_btc_price/usdt_btc_price

# %%
def

# %%
core_usdt_binance

# %%
for i in core_usdt_binance:
    print(i)
    ticker = binance.fetch_ticker(i+'/USDT')
    print(ticker['close'])
# Out:
# BTC
# 19025.36
# ETH
# 1339.09
# BNB
# 267.4
# BCC
# 0.0
# NEO
# 8.44
# LTC
# 52.32
# QTUM
# 2.886
# ADA
# 0.4535
# XRP
# 0.4074
# EOS
# 1.334
# TUSD
# 1.0
# IOTA
# 0.2628
# XLM
# 0.1158
# ONT
# 0.2212
# TRX
# 0.06015
# ETC
# 29.22
# ICX
# 0.2415
# VEN
# 0.0
# NULS
# 0.186
# VET
# 0.02273
# PAX
# 0.0
# BCH
# 113.2
# BSV
# 0.0
# USDC
# 0.9999
# LINK
# 6.967
# WAVES
# 3.989
# BTT
# 0.0
# USDS
# 0.0
# ONG
# 0.3306
# HOT
# 0.002034
# ZIL
# 0.03202
# ZRX
# 0.2711
# FET
# 0.0829
# BAT
# 0.3004
# XMR
# 142.0
# ZEC
# 54.2
# IOST
# 0.01211
# CELR
# 0.01516
# DASH
# 41.09
# NANO
# 0.0
# OMG
# 1.702
# THETA
# 1.043
# ENJ
# 0.4781
# MITH
# 0.02109
# MATIC
# 0.7419
# ATOM
# 14.119
# TFUEL
# 0.0517
# ONE
# 0.01911
# FTM
# 0.23
# ALGO
# 0.3256
# USDSB
# 0.0
# GTO
# 0.01974
# ERD
# 0.0
# DOGE
# 0.0594
# DUSK
# 0.1125
# ANKR
# 0.03035
# WIN
# 0.0001071
# COS
# 0.00595
# NPXS
# 0.0
# COCOS
# 0.6058
# MTL
# 1.069
# TOMO
# 0.4351
# PERL
# 0.02201
# DENT
# 0.000931
# MFT
# 0.005068
# KEY
# 0.004327
# ...

# %%
for i in core_krw_upbit:
    print(i)
    time.sleep(0.05)
    print(pyupbit.get_current_price("KRW-"+i))
# Out:
# BTC
# 26870000.0
# ETH
# 1889000.0
# NEO
# 11910.0
# MTL
# 1510.0
# XRP
# 578.0
# ETC
# 41260.0
# OMG
# 2400.0
# SNT
# 41.7
# WAVES
# 5615.0
# XEM
# 56.7
# QTUM
# 4080.0
# LSK
# 1355.0
# STEEM
# 301.0
# XLM
# 163.0
# ARDR
# 138.0
# ARK
# 541.0
# STORJ
# 650.0
# GRS
# 475.0
# REP
# 9960.0
# ADA
# 639.0
# SBD
# 3500.0
# POWR
# 274.0
# BTG
# 29890.0
# ICX
# 341.0
# EOS
# 1880.0
# TRX
# 85.1
# SC
# 5.01
# ONT
# 312.0
# ZIL
# 45.3
# POLY
# 281.0
# ZRX
# 383.0
# LOOM
# 85.7
# BCH
# 159750.0
# BAT
# 425.0
# IOST
# 17.1
# RFR
# 8.53
# CVC
# 184.0
# IQ
# 7.13
# IOTA
# 372.0
# MFT
# 7.13
# ONG
# 468.0
# GAS
# 3315.0
# UPP
# 85.3
# ELF
# 184.0
# KNC
# 1865.0
# BSV
# 68890.0
# THETA
# 1475.0
# QKC
# 19.3
# BTT
# 0.0011
# MOC
# 114.0
# ENJ
# 674.0
# TFUEL
# 73.2
# MANA
# 1005.0
# ANKR
# 42.9
# AERGO
# 189.0
# ATOM
# 19860.0
# TT
# 7.06
# CRE
# 5.7
# MBL
# 4.91
# WAXP
# 122.0
# HBAR
# 81.6
# MED
# 27.9
# MLK
# 455.0
# STPT
# 60.4
# ORBS
# 48.6
# VET
# 32.2
# CHZ
# 323.0
# STMX
# 10.1
# DKA
# 57.1
# ...

# %%
len(core_usdt)
# Out:
# 408

# %%
core_usdt_binance = core_usdt

# %%
tickers_upbit = pyupbit.get_tickers()

# %%
type(tickers_upbit)
# Out:
# list

# %%
len(tickers_upbit)
# Out:
# 287

# %%
core_krw_upbit = []

# %%
len(core_krw_upbit)
# Out:
# 113

# %%
for i in tickers_upbit:
    if 'KRW' in i:
        print(i)
        upbit_ticker = i.split("KRW-")[1]
        core_krw_upbit.append(upbit_ticker)
# Out:
# KRW-BTC
# KRW-ETH
# KRW-NEO
# KRW-MTL
# KRW-XRP
# KRW-ETC
# KRW-OMG
# KRW-SNT
# KRW-WAVES
# KRW-XEM
# KRW-QTUM
# KRW-LSK
# KRW-STEEM
# KRW-XLM
# KRW-ARDR
# KRW-ARK
# KRW-STORJ
# KRW-GRS
# KRW-REP
# KRW-ADA
# KRW-SBD
# KRW-POWR
# KRW-BTG
# KRW-ICX
# KRW-EOS
# KRW-TRX
# KRW-SC
# KRW-ONT
# KRW-ZIL
# KRW-POLY
# KRW-ZRX
# KRW-LOOM
# KRW-BCH
# KRW-BAT
# KRW-IOST
# KRW-RFR
# KRW-CVC
# KRW-IQ
# KRW-IOTA
# KRW-MFT
# KRW-ONG
# KRW-GAS
# KRW-UPP
# KRW-ELF
# KRW-KNC
# KRW-BSV
# KRW-THETA
# KRW-QKC
# KRW-BTT
# KRW-MOC
# KRW-ENJ
# KRW-TFUEL
# KRW-MANA
# KRW-ANKR
# KRW-AERGO
# KRW-ATOM
# KRW-TT
# KRW-CRE
# KRW-MBL
# KRW-WAXP
# KRW-HBAR
# KRW-MED
# KRW-MLK
# KRW-STPT
# KRW-ORBS
# KRW-VET
# KRW-CHZ
# KRW-STMX
# KRW-DKA
# KRW-HIVE
# KRW-KAVA
# KRW-AHT
# KRW-LINK
# KRW-XTZ
# KRW-BORA
# KRW-JST
# KRW-CRO
# KRW-TON
# KRW-SXP
# KRW-HUNT
# KRW-PLA
# KRW-DOT
# KRW-SRM
# KRW-MVL
# KRW-STRAX
# KRW-AQT
# KRW-GLM
# KRW-SSX
# KRW-META
# KRW-FCT2
# KRW-CBK
# KRW-SAND
# KRW-HUM
# KRW-DOGE
# KRW-STRK
# KRW-PUNDIX
# ...

# %%
core_usdt
# Out:
# ['BTC',
#  'ETH',
#  'BNB',
#  'BCC',
#  'NEO',
#  'LTC',
#  'QTUM',
#  'ADA',
#  'XRP',
#  'EOS',
#  'TUSD',
#  'IOTA',
#  'XLM',
#  'ONT',
#  'TRX',
#  'ETC',
#  'ICX',
#  'VEN',
#  'NULS',
#  'VET',
#  'PAX',
#  'BCH',
#  'BSV',
#  'USDC',
#  'LINK',
#  'WAVES',
#  'BTT',
#  'USDS',
#  'ONG',
#  'HOT',
#  'ZIL',
#  'ZRX',
#  'FET',
#  'BAT',
#  'XMR',
#  'ZEC',
#  'IOST',
#  'CELR',
#  'DASH',
#  'NANO',
#  'OMG',
#  'THETA',
#  'ENJ',
#  'MITH',
#  'MATIC',
#  'ATOM',
#  'TFUEL',
#  'ONE',
#  'FTM',
#  'ALGO',
#  'USDSB',
#  'GTO',
#  'ERD',
#  'DOGE',
#  'DUSK',
#  'ANKR',
#  'WIN',
#  'COS',
#  'NPXS',
#  'COCOS',
#  'MTL',
#  'TOMO',
#  'PERL',
#  'DENT',
#  'MFT',
#  'KEY',
#  'STORM',
#  'DOCK',
#  'WAN',
#  'FUN',
#  'CVC',
#  'CHZ',
#  'BAND',
#  'BUSD',
#  'BEAM',
#  'XTZ',
#  'REN',
#  'RVN',
#  'HC',
#  'HBAR',
#  'NKN',
#  'STX',
#  'KAVA',
#  'ARPA',
#  'IOTX',
#  'RLC',
#  'MCO',
#  'CTXC',
#  'TROY',
#  'VITE',
#  'FTT',
#  'EUR',
#  'OGN',
#  'DREP',
#  'BULL',
# ...

# %%
core = {}
for i in markets.keys():
    now_core = i.split("/")[1]
    if core.get(now_core) == None:
        core[now_core] = 1
    else:
        core[now_core] += 1

# %%
for i in core.keys():
    print(i)
    print(core[i])
    print('-------')
# Out:
# BTC
# 406
# -------
# ETH
# 218
# -------
# USDT
# 408
# -------
# BNB
# 270
# -------
# TUSD
# 31
# -------
# PAX
# 33
# -------
# USDC
# 40
# -------
# XRP
# 2
# -------
# USDS
# 3
# -------
# TRX
# 2
# -------
# BUSD
# 363
# -------
# NGN
# 10
# -------
# RUB
# 22
# -------
# TRY
# 78
# -------
# EUR
# 49
# -------
# ZAR
# 5
# -------
# BKRW
# 11
# -------
# IDRT
# 4
# -------
# GBP
# 23
# -------
# UAH
# 7
# -------
# BIDR
# 29
# -------
# AUD
# 27
# -------
# DAI
# 5
# -------
# BRL
# 36
# -------
# BVND
# 2
# -------
# VAI
# 2
# -------
# USDP
# 3
# -------
# DOGE
# 1
# -------
# UST
# 4
# -------
# DOT
# 1
# -------

# %%
# !pip install python-binance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 kB 193.5 kB/s eta 0:00:001m196.3 kB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 796.9 kB/s eta 0:00:0031m1.1 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.9/355.9 kB 324.0 kB/s eta 0:00:000:00:010:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.9/288.9 kB 2.2 MB/s eta 0:00:00m eta 0:00:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 992.6 kB/s eta 0:00:0031m3.6 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.4/289.4 kB 2.7 MB/s eta 0:00:00m eta 0:00:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.4/336.4 kB 5.1 MB/s eta 0:00:000:00:01
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
df['MA'] = ta.SMA(df['close'], 168)

# %%
df[['close','MA']].plot(figsize=(12,6))
plt.title("ETH - 6 Days", {"fontsize" : 20})
plt.show()

# %%
df['MA'] = ta.SMA(df['close'], 24)
df['5MA'] = ta.SMA(df['close'], 5)

#차트로 그려주자.
df[['close','MA','5MA']].plot(figsize=(12,6))
plt.title("ETH - 6 Days", {"fontsize" : 20})
plt.show()

# %%
price = pyupbit.get_current_price("KRW-XRP")
print(price)
# Out:
# 466.0

# %%
print(price)
# Out:
# 466.0

# %%
price = pyupbit.get_current_price("BTC-XRP")

# %%
print(price)
# Out:
# 1.636e-05

# %%
df = pyupbit.get_ohlcv("KRW-BTC")

# %%
print(df)
# Out:
#                            open        high         low       close  \
# 2022-01-03 09:00:00  57540000.0  57749000.0  56133000.0  56641000.0
# 2022-01-04 09:00:00  56640000.0  57685000.0  56000000.0  56023000.0
# 2022-01-05 09:00:00  56023000.0  57100000.0  52701000.0  53854000.0
# 2022-01-06 09:00:00  53854000.0  54300000.0  52388000.0  53239000.0
# 2022-01-07 09:00:00  53240000.0  53358000.0  50900000.0  51449000.0
# ...                         ...         ...         ...         ...
# 2022-07-17 09:00:00  27856000.0  28481000.0  27453000.0  27505000.0
# 2022-07-18 09:00:00  27505000.0  29613000.0  27450000.0  29322000.0
# 2022-07-19 09:00:00  29322000.0  31050000.0  28476000.0  30660000.0
# 2022-07-20 09:00:00  30646000.0  31831000.0  30128000.0  30505000.0
# 2022-07-21 09:00:00  30500000.0  30849000.0  29621000.0  29868000.0
#
#                            volume         value
# 2022-01-03 09:00:00   6304.958564  3.600635e+11
# 2022-01-04 09:00:00   6053.445802  3.425126e+11
# ...

# %%
import pandas as pd

# %%
pd.options.display.float_format = '{:.3f}'.format

df.describe()
# Out:
#               open         high          low        close  volume  \
# count      200.000      200.000      200.000      200.000 200.000
# mean  30696630.000 30770665.000 30613100.000 30691650.000  92.420
# std     530668.501   536539.323   527235.408   533980.113  54.615
# min   29728000.000 29782000.000 29621000.000 29749000.000   7.031
# 25%   30188250.000 30242000.000 30129000.000 30189750.000  53.117
# 50%   30737000.000 30797000.000 30645000.000 30732000.000  80.316
# 75%   31148250.000 31247750.000 31041750.000 31150000.000 115.966
# max   31789000.000 31831000.000 31707000.000 31789000.000 335.322
#
#                 value
# count         200.000
# mean   2834119846.147
# std    1670110054.510
# min     220384300.885
# 25%    1652994339.305
# 50%    2444866352.410
# 75%    3579197300.119
# max   10068542529.919

# %%
df = pyupbit.get_ohlcv("KRW-BTC", interval="minute10")
print(df)
# Out:
#                             open         high          low        close  \
# 2022-07-20 15:00:00 30786000.000 30853000.000 30786000.000 30852000.000
# 2022-07-20 15:10:00 30852000.000 30948000.000 30834000.000 30917000.000
# 2022-07-20 15:20:00 30921000.000 31137000.000 30921000.000 31117000.000
# 2022-07-20 15:30:00 31117000.000 31193000.000 30993000.000 31051000.000
# 2022-07-20 15:40:00 31052000.000 31149000.000 31011000.000 31148000.000
# ...                          ...          ...          ...          ...
# 2022-07-21 23:30:00 29764000.000 29782000.000 29621000.000 29757000.000
# 2022-07-21 23:40:00 29728000.000 29797000.000 29716000.000 29749000.000
# 2022-07-21 23:50:00 29749000.000 29846000.000 29734000.000 29841000.000
# 2022-07-22 00:00:00 29841000.000 29910000.000 29814000.000 29834000.000
# 2022-07-22 00:10:00 29838000.000 29850000.000 29790000.000 29800000.000
#
#                      volume          value
# 2022-07-20 15:00:00  43.311 1335083904.253
# ...

# %%
access_key = "dkVTGuyAmakhSXIATTrkcAVtSFAZ6LCqNfjsRdcB"
secret_key = "xDkJELeODZUxJkjGlzVJoZDwYb5e32CS59a1T2OF"
upbit = pyupbit.Upbit(access_key, secret_key)

print(upbit)

# %%
print(upbit.get_balances())
# Out:
# [{'currency': 'BTC', 'balance': '0.00055358', 'locked': '0', 'avg_buy_price': '38683000', 'avg_buy_price_modified': False, 'unit_currency': 'KRW'}, {'currency': 'KRW', 'balance': '1.05629564', 'locked': '0', 'avg_buy_price': '0', 'avg_buy_price_modified': True, 'unit_currency': 'KRW'}, {'currency': 'ETH', 'balance': '2.33313136', 'locked': '0', 'avg_buy_price': '2852000', 'avg_buy_price_modified': False, 'unit_currency': 'KRW'}, {'currency': 'SAND', 'balance': '4624.19864656', 'locked': '0', 'avg_buy_price': '4319.826', 'avg_buy_price_modified': False, 'unit_currency': 'KRW'}, {'currency': 'APENFT', 'balance': '2850.21114822', 'locked': '0', 'avg_buy_price': '0', 'avg_buy_price_modified': False, 'unit_currency': 'KRW'}, {'currency': 'LUNA2', 'balance': '238.29125655', 'locked': '0', 'avg_buy_price': '0', 'avg_buy_price_modified': False, 'unit_currency': 'KRW'}]
