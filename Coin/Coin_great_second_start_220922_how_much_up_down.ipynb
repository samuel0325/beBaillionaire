# %%
import pyupbit
import ccxt
import time
import yfinance as yf
from datetime import datetime

# %%
#바이낸스 티커 가져오기
binance = ccxt.binance()
markets = binance.fetch_tickers()

#바이낸스에서 USDT base 티커 가져오기
core_usdt_binance = []
for i in markets.keys():
    if '/' in i:
        now_core = i.split("/")[1]
        now_currrency = i.split("/")[0]
        if now_core == 'USDT':
            core_usdt_binance.append(now_currrency)

#업비트 티커 가져오기
tickers_upbit = pyupbit.get_tickers()        

#업비트에서 krw base 티커 가져오기
core_krw_upbit = []
for i in tickers_upbit:
    if 'KRW' in i:
        upbit_ticker = i.split("KRW-")[1]
        core_krw_upbit.append(upbit_ticker)        

#업비트 바이낸스 공통 티커 저장하기
upbit_binance_tickers = []
for i in core_usdt_binance:
    if i in core_krw_upbit:
        upbit_binance_tickers.append(i)

# %%
def now_kimchi():
    binance_updown_dict = {}
    upbit_updown_dict = {}
    print("현재 시간 :", time.strftime('%Y-%m-%d %H:%M:%S'))
    USDKRW = yf.Ticker("USDKRW=X")
    now_usd_krw = USDKRW.info.get('regularMarketPrice')
    print('$1 가격 : ₩',now_usd_krw)
    count = 0
    for i in upbit_binance_tickers:
        time.sleep(0.05)
        now_upbit_price = pyupbit.get_current_price("KRW-"+i)
        now_binance_price = binance.fetch_ticker(i+'/USDT')['close']
        today_open_upbit = pyupbit.get_ohlcv("KRW-"+i, count=1)['open'][0]
        today_open_binance = binance.fetch_ticker(i+'/USDT')['open']
        
        if now_binance_price == 0:
            continue
        count+=1
        print(str(count)+". "+i)
        print("Now : $",now_binance_price)
        print("Open : $",today_open_binance)
        print("Binance Change :",round((now_binance_price-today_open_binance)/today_open_binance,3),'%')
        print()
        binance_updown_dict[i] = (now_binance_price-today_open_binance)/today_open_binance
        print("Now : ₩",now_upbit_price)
        print("Open : ₩",today_open_upbit)
        print("Upbit Change :",round((now_upbit_price-today_open_upbit)/today_open_upbit,3),'%')
        upbit_updown_dict[i] = (now_upbit_price-today_open_upbit)/today_open_upbit
        print()
        print("Kimchi Premium :",round((now_upbit_price*100/(now_binance_price*now_usd_krw))-100,3),"%")
        print('-------------------')
    return binance_updown_dict, upbit_updown_dict

# %%
now_binan_dict, now_upbit_dict = now_kimchi()
# Out:
# 현재 시간 : 2022-09-22 23:31:44
# $1 가격 : ₩ 1403.83
# 1. BTC
# Now : $ 18982.46
# Open : $ 19396.71
# Binance Change : -0.021 %
#
# Now : ₩ 27081000.0
# Open : ₩ 26523000.0
# Upbit Change : 0.021 %
#
# Kimchi Premium : 1.624 %
# -------------------
# 2. ETH
# Now : $ 1277.32
# Open : $ 1352.2
# Binance Change : -0.055 %
#
# Now : ₩ 1822000.0
# Open : ₩ 1791000.0
# Upbit Change : 0.017 %
#
# Kimchi Premium : 1.609 %
# -------------------
# 3. NEO
# Now : $ 8.32
# Open : $ 8.43
# Binance Change : -0.013 %
#
# Now : ₩ 11890.0
# Open : ₩ 11560.0
# Upbit Change : 0.029 %
#
# Kimchi Premium : 1.799 %
# -------------------
# 4. QTUM
# Now : $ 2.845
# Open : $ 2.887
# Binance Change : -0.015 %
#
# Now : ₩ 4060.0
# Open : ₩ 3955.0
# Upbit Change : 0.027 %
#
# Kimchi Premium : 1.655 %
# -------------------
# 5. ADA
# Now : $ 0.4503
# Open : $ 0.4494
# Binance Change : 0.002 %
#
# Now : ₩ 648.0
# Open : ₩ 633.0
# Upbit Change : 0.024 %
#
# Kimchi Premium : 2.508 %
# -------------------
# 6. XRP
# Now : $ 0.4443
# Open : $ 0.4059
# Binance Change : 0.095 %
#
# Now : ₩ 633.0
# Open : ₩ 565.0
# Upbit Change : 0.12 %
#
# Kimchi Premium : 1.488 %
# -------------------
# 7. EOS
# Now : $ 1.221
# Open : $ 1.298
# Binance Change : -0.059 %
#
# Now : ₩ 1745.0
# Open : ₩ 1725.0
# Upbit Change : 0.012 %
#
# Kimchi Premium : 1.804 %
# -------------------
# 8. IOTA
# Now : $ 0.2646
# Open : $ 0.2602
# Binance Change : 0.017 %
#
# Now : ₩ 377.0
# Open : ₩ 362.0
# Upbit Change : 0.041 %
#
# Kimchi Premium : 1.493 %
# -------------------
# 9. XLM
# Now : $ 0.1202
# Open : $ 0.1149
# Binance Change : 0.046 %
#
# Now : ₩ 171.0
# Open : ₩ 158.0
# Upbit Change : 0.082 %
#
# Kimchi Premium : 1.339 %
# -------------------
# 10. ONT
# Now : $ 0.2215
# Open : $ 0.2221
# Binance Change : -0.003 %
#
# Now : ₩ 316.0
# Open : ₩ 305.0
# Upbit Change : 0.036 %
#
# Kimchi Premium : 1.625 %
# -------------------
# 11. TRX
# Now : $ 0.05954
# Open : $ 0.05988
# Binance Change : -0.006 %
#
# Now : ₩ 84.9
# Open : ₩ 84.8
# Upbit Change : 0.001 %
#
# Kimchi Premium : 1.574 %
# -------------------
# 12. ETC
# Now : $ 28.23
# Open : $ 29.28
# Binance Change : -0.036 %
#
# Now : ₩ 40290.0
# Open : ₩ 39910.0
# Upbit Change : 0.01 %
#
# Kimchi Premium : 1.665 %
# -------------------
# 13. ICX
# Now : $ 0.2386
# Open : $ 0.2407
# Binance Change : -0.009 %
#
# Now : ₩ 341.0
# Open : ₩ 331.0
# Upbit Change : 0.03 %
#
# Kimchi Premium : 1.805 %
# -------------------
# 14. VET
# Now : $ 0.02265
# Open : $ 0.0227
# Binance Change : -0.002 %
#
# Now : ₩ 32.3
# Open : ₩ 31.5
# Upbit Change : 0.025 %
#
# Kimchi Premium : 1.583 %
# -------------------
# 15. BCH
# Now : $ 115.4
# Open : $ 114.8
# Binance Change : 0.005 %
#
# Now : ₩ 164700.0
# Open : ₩ 156450.0
# Upbit Change : 0.053 %
#
# Kimchi Premium : 1.665 %
# -------------------
# 16. LINK
# Now : $ 6.956
# Open : $ 7.035
# Binance Change : -0.011 %
#
# Now : ₩ 9910.0
# Open : ₩ 9605.0
# Upbit Change : 0.032 %
#
# Kimchi Premium : 1.484 %
# -------------------
# 17. WAVES
# Now : $ 3.969
# Open : $ 3.962
# Binance Change : 0.002 %
#
# Now : ₩ 5660.0
# Open : ₩ 5535.0
# Upbit Change : 0.023 %
#
# Kimchi Premium : 1.583 %
# -------------------
# 18. ONG
# Now : $ 0.332
# Open : $ 0.3333
# Binance Change : -0.004 %
#
# Now : ₩ 473.0
# Open : ₩ 465.0
# Upbit Change : 0.017 %
#
# Kimchi Premium : 1.487 %
# -------------------
# 19. ZIL
# Now : $ 0.03277
# Open : $ 0.03177
# Binance Change : 0.031 %
#
# Now : ₩ 46.7
# Open : ₩ 44.7
# Upbit Change : 0.045 %
#
# Kimchi Premium : 1.514 %
# -------------------
# 20. ZRX
# Now : $ 0.2704
# Open : $ 0.2707
# Binance Change : -0.001 %
#
# Now : ₩ 385.0
# Open : ₩ 372.0
# Upbit Change : 0.035 %
#
# Kimchi Premium : 1.424 %
# -------------------
# 21. BAT
# Now : $ 0.3013
# Open : $ 0.3006
# Binance Change : 0.002 %
#
# Now : ₩ 430.0
# Open : ₩ 414.0
# Upbit Change : 0.039 %
#
# Kimchi Premium : 1.661 %
# -------------------
# 22. IOST
# Now : $ 0.01213
# Open : $ 0.01207
# Binance Change : 0.005 %
#
# Now : ₩ 17.4
# Open : ₩ 16.7
# Upbit Change : 0.042 %
#
# Kimchi Premium : 2.182 %
# -------------------
# 23. OMG
# Now : $ 1.718
# Open : $ 1.703
# Binance Change : 0.009 %
#
# Now : ₩ 2455.0
# Open : ₩ 2360.0
# Upbit Change : 0.04 %
#
# Kimchi Premium : 1.792 %
# -------------------
# 24. THETA
# Now : $ 1.085
# Open : $ 1.052
# Binance Change : 0.031 %
#
# Now : ₩ 1550.0
# Open : ₩ 1485.0
# Upbit Change : 0.044 %
#
# Kimchi Premium : 1.762 %
# -------------------
# 25. ENJ
# Now : $ 0.4748
# Open : $ 0.4751
# Binance Change : -0.001 %
#
# Now : ₩ 676.0
# Open : ₩ 653.0
# Upbit Change : 0.035 %
#
# Kimchi Premium : 1.42 %
# -------------------
# 26. MATIC
# Now : $ 0.7397
# Open : $ 0.7416
# Binance Change : -0.003 %
#
# Now : ₩ 1060.0
# Open : ₩ 1010.0
# Upbit Change : 0.05 %
#
# Kimchi Premium : 2.079 %
# -------------------
# 27. ATOM
# Now : $ 14.227
# Open : $ 14.283
# Binance Change : -0.004 %
#
# Now : ₩ 20290.0
# Open : ₩ 19250.0
# Upbit Change : 0.054 %
#
# Kimchi Premium : 1.591 %
# -------------------
# 28. TFUEL
# Now : $ 0.0535
# Open : $ 0.0516
# Binance Change : 0.037 %
#
# Now : ₩ 76.6
# Open : ₩ 74.2
# Upbit Change : 0.032 %
#
# Kimchi Premium : 1.991 %
# -------------------
# 29. ALGO
# Now : $ 0.3647
# Open : $ 0.32
# Binance Change : 0.14 %
#
# Now : ₩ 521.0
# Open : ₩ 484.0
# Upbit Change : 0.076 %
#
# Kimchi Premium : 1.762 %
# -------------------
# 30. DOGE
# Now : $ 0.05895
# Open : $ 0.0591
# Binance Change : -0.003 %
#
# Now : ₩ 84.0
# Open : ₩ 82.2
# Upbit Change : 0.022 %
#
# Kimchi Premium : 1.503 %
# -------------------
# 31. ANKR
# Now : $ 0.0303
# Open : $ 0.0305
# Binance Change : -0.007 %
#
# Now : ₩ 43.1
# Open : ₩ 41.7
# Upbit Change : 0.034 %
#
# Kimchi Premium : 1.326 %
# -------------------
# 32. MTL
# Now : $ 1.059
# Open : $ 1.081
# Binance Change : -0.02 %
#
# Now : ₩ 1515.0
# Open : ₩ 1475.0
# Upbit Change : 0.027 %
#
# Kimchi Premium : 1.907 %
# -------------------
# 33. MFT
# Now : $ 0.004964
# Open : $ 0.00497
# Binance Change : -0.001 %
#
# Now : ₩ 7.11
# Open : ₩ 7.0
# Upbit Change : 0.016 %
#
# Kimchi Premium : 2.029 %
# -------------------
# 34. CVC
# Now : $ 0.129
# Open : $ 0.1301
# Binance Change : -0.008 %
#
# Now : ₩ 184.0
# Open : ₩ 179.0
# Upbit Change : 0.028 %
#
# Kimchi Premium : 1.605 %
# -------------------
# 35. CHZ
# Now : $ 0.2454
# Open : $ 0.2348
# Binance Change : 0.045 %
#
# Now : ₩ 350.0
# Open : ₩ 329.0
# Upbit Change : 0.064 %
#
# Kimchi Premium : 1.597 %
# -------------------
# 36. XTZ
# Now : $ 1.476
# Open : $ 1.46
# Binance Change : 0.011 %
#
# Now : ₩ 2110.0
# Open : ₩ 2020.0
# Upbit Change : 0.045 %
#
# Kimchi Premium : 1.831 %
# -------------------
# 37. HBAR
# Now : $ 0.0592
# Open : $ 0.0582
# Binance Change : 0.017 %
#
# Now : ₩ 84.4
# Open : ₩ 81.4
# Upbit Change : 0.037 %
#
# Kimchi Premium : 1.556 %
# -------------------
# 38. STX
# Now : $ 0.33
# Open : $ 0.331
# Binance Change : -0.003 %
#
# Now : ₩ 473.0
# Open : ₩ 462.0
# Upbit Change : 0.024 %
#
# Kimchi Premium : 2.102 %
# -------------------
# 39. KAVA
# Now : $ 1.509
# Open : $ 1.474
# Binance Change : 0.024 %
#
# Now : ₩ 2150.0
# Open : ₩ 2055.0
# Upbit Change : 0.046 %
#
# Kimchi Premium : 1.493 %
# -------------------
# 40. LSK
# Now : $ 0.945
# Open : $ 0.944
# Binance Change : 0.001 %
#
# Now : ₩ 1345.0
# Open : ₩ 1330.0
# Upbit Change : 0.011 %
#
# Kimchi Premium : 1.386 %
# -------------------
# 41. MBL
# Now : $ 0.003475
# Open : $ 0.003465
# Binance Change : 0.003 %
#
# Now : ₩ 4.96
# Open : ₩ 4.87
# Upbit Change : 0.018 %
#
# Kimchi Premium : 1.675 %
# -------------------
# 42. STPT
# Now : $ 0.04389
# Open : $ 0.0427
# Binance Change : 0.028 %
#
# Now : ₩ 62.5
# Open : ₩ 60.7
# Upbit Change : 0.03 %
#
# Kimchi Premium : 1.438 %
# -------------------
# 43. SOL
# Now : $ 31.99
# Open : $ 32.11
# Binance Change : -0.004 %
#
# Now : ₩ 45230.0
# Open : ₩ 43550.0
# Upbit Change : 0.039 %
#
# Kimchi Premium : 0.716 %
# -------------------
# 44. HIVE
# Now : $ 0.5018
# Open : $ 0.506
# Binance Change : -0.008 %
#
# Now : ₩ 715.0
# Open : ₩ 707.0
# Upbit Change : 0.011 %
#
# Kimchi Premium : 1.499 %
# -------------------
# 45. ARDR
# Now : $ 0.0974
# Open : $ 0.0979
# Binance Change : -0.005 %
#
# Now : ₩ 140.0
# Open : ₩ 137.0
# Upbit Change : 0.022 %
#
# Kimchi Premium : 2.389 %
# -------------------
# 46. STMX
# Now : $ 0.007125
# Open : $ 0.007188
# Binance Change : -0.009 %
#
# Now : ₩ 10.2
# Open : ₩ 9.96
# Upbit Change : 0.024 %
#
# Kimchi Premium : 1.977 %
# -------------------
# 47. KNC
# Now : $ 1.228
# Open : $ 1.288
# Binance Change : -0.047 %
#
# Now : ₩ 1750.0
# Open : ₩ 1745.0
# Upbit Change : 0.003 %
#
# Kimchi Premium : 1.514 %
# -------------------
# 48. REP
# Now : $ 7.15
# Open : $ 7.05
# Binance Change : 0.014 %
#
# Now : ₩ 10180.0
# Open : ₩ 10070.0
# Upbit Change : 0.011 %
#
# Kimchi Premium : 1.421 %
# -------------------
# 49. SC
# Now : $ 0.00352
# Open : $ 0.0035
# Binance Change : 0.006 %
#
# Now : ₩ 5.02
# Open : ₩ 4.92
# Upbit Change : 0.02 %
#
# Kimchi Premium : 1.589 %
# -------------------
# 50. SXP
# Now : $ 0.3376
# Open : $ 0.3368
# Binance Change : 0.002 %
#
# Now : ₩ 481.0
# Open : ₩ 464.0
# Upbit Change : 0.037 %
#
# Kimchi Premium : 1.491 %
# -------------------
# 51. STORJ
# Now : $ 0.4575
# Open : $ 0.4602
# Binance Change : -0.006 %
#
# Now : ₩ 655.0
# Open : ₩ 636.0
# Upbit Change : 0.03 %
#
# Kimchi Premium : 1.985 %
# -------------------
# 52. MANA
# Now : $ 0.7065
# Open : $ 0.7095
# Binance Change : -0.004 %
#
# Now : ₩ 1005.0
# Open : ₩ 979.0
# Upbit Change : 0.027 %
#
# Kimchi Premium : 1.33 %
# -------------------
# 53. JST
# Now : $ 0.02494
# Open : $ 0.02513
# Binance Change : -0.008 %
#
# Now : ₩ 35.5
# Open : ₩ 35.1
# Upbit Change : 0.011 %
#
# Kimchi Premium : 1.395 %
# -------------------
# 54. SRM
# Now : $ 0.762
# Open : $ 0.766
# Binance Change : -0.005 %
#
# Now : ₩ 1090.0
# Open : ₩ 1055.0
# Upbit Change : 0.033 %
#
# Kimchi Premium : 1.896 %
# -------------------
# 55. SAND
# Now : $ 0.8634
# Open : $ 0.8522
# Binance Change : 0.013 %
#
# Now : ₩ 1230.0
# Open : ₩ 1170.0
# Upbit Change : 0.051 %
#
# Kimchi Premium : 1.48 %
# -------------------
# 56. DOT
# Now : $ 6.39
# Open : $ 6.36
# Binance Change : 0.005 %
#
# Now : ₩ 9105.0
# Open : ₩ 8805.0
# Upbit Change : 0.034 %
#
# Kimchi Premium : 1.5 %
# -------------------
# 57. AVAX
# Now : $ 17.3
# Open : $ 17.02
# Binance Change : 0.016 %
#
# Now : ₩ 24730.0
# Open : ₩ 23770.0
# Upbit Change : 0.04 %
#
# Kimchi Premium : 1.827 %
# -------------------
# 58. AAVE
# Now : $ 75.0
# Open : $ 76.4
# Binance Change : -0.018 %
#
# Now : ₩ 106850.0
# Open : ₩ 103000.0
# Upbit Change : 0.037 %
#
# Kimchi Premium : 1.484 %
# -------------------
# 59. NEAR
# Now : $ 3.789
# Open : $ 3.878
# Binance Change : -0.023 %
#
# Now : ₩ 5400.0
# Open : ₩ 5230.0
# Upbit Change : 0.033 %
#
# Kimchi Premium : 1.521 %
# -------------------
# 60. AXS
# Now : $ 12.1
# Open : $ 12.34
# Binance Change : -0.019 %
#
# Now : ₩ 17230.0
# Open : ₩ 16960.0
# Upbit Change : 0.016 %
#
# Kimchi Premium : 1.434 %
# -------------------
# 61. STRAX
# Now : $ 0.514
# Open : $ 0.51
# Binance Change : 0.008 %
#
# Now : ₩ 732.0
# Open : ₩ 729.0
# Upbit Change : 0.004 %
#
# Kimchi Premium : 1.446 %
# -------------------
# 62. XEM
# Now : $ 0.0406
# Open : $ 0.0401
# Binance Change : 0.012 %
#
# Now : ₩ 58.0
# Open : ₩ 55.8
# Upbit Change : 0.039 %
#
# Kimchi Premium : 1.762 %
# -------------------
# 63. 1INCH
# Now : $ 0.582
# Open : $ 0.589
# Binance Change : -0.012 %
#
# Now : ₩ 828.0
# Open : ₩ 810.0
# Upbit Change : 0.022 %
#
# Kimchi Premium : 1.343 %
# -------------------
# 64. CELO
# Now : $ 0.784
# Open : $ 0.768
# Binance Change : 0.021 %
#
# Now : ₩ 1120.0
# Open : ₩ 1055.0
# Upbit Change : 0.062 %
#
# Kimchi Premium : 1.762 %
# -------------------
# 65. PUNDIX
# Now : $ 0.498
# Open : $ 0.502
# Binance Change : -0.008 %
#
# Now : ₩ 709.0
# Open : ₩ 706.0
# Upbit Change : 0.004 %
#
# Kimchi Premium : 1.415 %
# -------------------
# 66. BTG
# Now : $ 20.82
# Open : $ 21.12
# Binance Change : -0.014 %
#
# Now : ₩ 29730.0
# Open : ₩ 29280.0
# Upbit Change : 0.015 %
#
# Kimchi Premium : 1.718 %
# -------------------
# 67. FLOW
# Now : $ 1.675
# Open : $ 1.68
# Binance Change : -0.003 %
#
# Now : ₩ 2385.0
# Open : ₩ 2330.0
# Upbit Change : 0.024 %
#
# Kimchi Premium : 1.428 %
# -------------------
# 68. WAXP
# Now : $ 0.0862
# Open : $ 0.0865
# Binance Change : -0.003 %
#
# Now : ₩ 123.0
# Open : ₩ 121.0
# Upbit Change : 0.017 %
#
# Kimchi Premium : 1.644 %
# -------------------
# 69. XEC
# Now : $ 3.849e-05
# Open : $ 3.876e-05
# Binance Change : -0.007 %
#
# Now : ₩ 0.0548
# Open : ₩ 0.0542
# Upbit Change : 0.011 %
#
# Kimchi Premium : 1.419 %
# -------------------
# 70. ELF
# Now : $ 0.131
# Open : $ 0.1318
# Binance Change : -0.006 %
#
# Now : ₩ 186.0
# Open : ₩ 185.0
# Upbit Change : 0.005 %
#
# Kimchi Premium : 1.141 %
# -------------------
# 71. POLY
# Now : $ 0.1977
# Open : $ 0.2
# Binance Change : -0.012 %
#
# Now : ₩ 283.0
# Open : ₩ 279.0
# Upbit Change : 0.014 %
#
# Kimchi Premium : 1.968 %
# -------------------
# 72. POWR
# Now : $ 0.1936
# Open : $ 0.195
# Binance Change : -0.007 %
#
# Now : ₩ 276.0
# Open : ₩ 271.0
# Upbit Change : 0.018 %
#
# Kimchi Premium : 1.552 %
# -------------------
# 73. PLA
# Now : $ 0.32
# Open : $ 0.322
# Binance Change : -0.006 %
#
# Now : ₩ 456.0
# Open : ₩ 449.0
# Upbit Change : 0.016 %
#
# Kimchi Premium : 1.508 %
# -------------------
# 74. T
# Now : $ 0.0306
# Open : $ 0.0312
# Binance Change : -0.019 %
#
# Now : ₩ 43.6
# Open : ₩ 43.1
# Upbit Change : 0.012 %
#
# Kimchi Premium : 1.496 %
# -------------------
# 75. GMT
# Now : $ 0.6251
# Open : $ 0.6206
# Binance Change : 0.007 %
#
# Now : ₩ 883.0
# Open : ₩ 856.0
# Upbit Change : 0.032 %
#
# Kimchi Premium : 0.623 %
# -------------------
# 76. STEEM
# Now : $ 0.2151
# Open : $ 0.2125
# Binance Change : 0.012 %
#
# Now : ₩ 307.0
# Open : ₩ 299.0
# Upbit Change : 0.027 %
#
# Kimchi Premium : 1.668 %
# -------------------

# %%
def most123(now_binan_dict, now_upbit_dict):
    sort_binan_dic = sorted( now_binan_dict.items(), key = lambda pair : pair[1] )
    sort_upbit_dic = sorted( now_upbit_dict.items(), key = lambda pair : pair[1] )
    print('Binance most down :',sort_binan_dic[0])
    print('Upbit most down :',sort_upbit_dic[0])
    print('Binance most up :',sort_binan_dic[-1])
    print('Upbit most up :',sort_upbit_dic[-1])

# %%
most123(now_binan_dict, now_upbit_dict)
# Out:
# Binance most down : ('EOS', -0.05932203389830505)
# Upbit most down : ('TRX', 0.0011792452830189685)
# Binance most up : ('ALGO', 0.13968750000000005)
# Upbit most up : ('XRP', 0.12035398230088495)
