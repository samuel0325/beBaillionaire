# %%
import requests
resp = requests.get("http://api.bithumb.com/public/ticker/BTC")
print(resp)
# Out:
# <Response [200]>

# %%
print(resp.content)
# Out:
# b'{"status":"0000","data":{"opening_price":"29813000","closing_price":"29837000","min_price":"29738000","max_price":"29885000","units_traded":"69.3354856","acc_trade_value":"2067469816.138","prev_closing_price":"29812000","units_traded_24H":"6936.36135095","acc_trade_value_24H":"211424707180.0972","fluctate_24H":"-1747000","fluctate_rate_24H":"-5.53","date":"1658416876249"}}'

# %%
eth = requests.get("http://api.bithumb.com/public/ticker/ETH")
print(eth.content)
# Out:
# b'{"status":"0000","data":{"opening_price":"1982000","closing_price":"1990000","min_price":"1980000","max_price":"1996000","units_traded":"326.52004351","acc_trade_value":"649642206.4999","prev_closing_price":"1981000","units_traded_24H":"31742.13522514","acc_trade_value_24H":"63369307963.7148","fluctate_24H":"-100000","fluctate_rate_24H":"-4.78","date":"1658416886239"}}'

# %%
eth_start_price = int(str(eth.content).split("\"")[9])
eth_max_price = int(str(eth.content).split("\"")[21])

# %%
eth_max_price
# Out:
# 1996000

# %%
# !pip install pybithumb

# %%
import pybithumb
tickers = pybithumb.get_tickers()
print(tickers)
# Out:
# ['BTC', 'ETH', 'ETC', 'XRP', 'BCH', 'QTUM', 'BTG', 'EOS', 'ICX', 'TRX', 'ELF', 'OMG', 'KNC', 'GLM', 'ZIL', 'WAXP', 'POWR', 'LRC', 'STEEM', 'STRAX', 'ZRX', 'REP', 'SNT', 'ADA', 'CTXC', 'BAT', 'THETA', 'LOOM', 'WAVES', 'LINK', 'ENJ', 'VET', 'MTL', 'IOST', 'QKC', 'ATOLO', 'AMO', 'BSV', 'ORBS', 'TFUEL', 'VALOR', 'CON', 'ANKR', 'MIX', 'CRO', 'FX', 'CHR', 'MBL', 'MXC', 'FCT2', 'TRV', 'DAD', 'WOM', 'SOC', 'BOA', 'MEV', 'SXP', 'COS', 'EL', 'BASIC', 'HIVE', 'XPR', 'VRA', 'FIT', 'EGG', 'BORA', 'ARPA', 'CTC', 'APM', 'CKB', 'AERGO', 'ANW', 'CENNZ', 'EVZ', 'CYCLUB', 'SRM', 'QTCON', 'UNI', 'YFI', 'UMA', 'AAVE', 'COMP', 'REN', 'BAL', 'RSR', 'NMR', 'RLC', 'UOS', 'SAND', 'GOM2', 'BEL', 'OBSR', 'ORC', 'POLA', 'AWO', 'ADP', 'DVI', 'GHX', 'MVC', 'BLY', 'WOZX', 'ANV', 'GRT', 'MM', 'BIOT', 'XNO', 'SNX', 'SOFI', 'COLA', 'OXT', 'LINA', 'MAP', 'AQT', 'PLA', 'WIKEN', 'CTSI', 'MANA', 'LPT', 'MKR', 'SUSHI', 'ASM', 'PUNDIX', 'CELR', 'ARW', 'FRONT', 'RLY', 'OCEAN', 'BFC', 'ALICE', 'OGN', 'COTI', 'CAKE', 'BNT', 'X
# ...

# %%
type(tickers)
# Out:
# list

# %%
len(tickers)
# Out:
# 193

# %%
btc_price = pybithumb.get_current_price("BTC")

# %%
btc_price
# Out:
# 29834000.0

# %%
import time

# %%
import time
iter_count = 0
while True:
    btc_price = pybithumb.get_current_price("BTC")
    print(btc_price)
    iter_count+=1
    time.sleep(1)
    print("iter_count : ",iter_count)
# Out:
# 45439000.0
# iter_count :  1
# 45439000.0
# iter_count :  2
# 45439000.0
# iter_count :  3
# 45439000.0
# iter_count :  4
# 45439000.0
# iter_count :  5
# 45437000.0
# iter_count :  6
# 45437000.0
# iter_count :  7
# 45439000.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2c2e28763bb9> in <module>
#       5     print(btc_price)
#       6     iter_count+=1
# ----> 7     time.sleep(1)
#       8     print("iter_count : ",iter_count)
#
# KeyboardInterrupt:

# %%
for ticker in tickers:
    price = pybithumb.get_current_price(ticker)
    print(ticker,price)
    time.sleep(0.1)
# Out:
# BTC 29819000.0
# ETH 1988000.0
# ETC 31900.0
# XRP 465.1
# BCH 161100.0
# QTUM 4013.0
# BTG 24360.0
# EOS 1351.0
# ICX 379.6
# TRX 89.03
# ELF 230.8
# OMG 2474.0
# KNC 1861.0
# GLM 324.8
# ZIL 53.28
# WAXP 133.8
# POWR 315.3
# LRC 552.5
# STEEM 317.0
# STRAX 930.3
# ZRX 410.2
# REP 10770.0
# SNT 39.6
# ADA 636.1
# CTXC 186.2
# BAT 517.0
# THETA 1617.0
# LOOM 65.15
# WAVES 7275.0
# LINK 9025.0
# ENJ 806.4
# VET 32.8
# MTL 1930.0
# IOST 17.99
# QKC 13.83
# ATOLO 23.6
# AMO 1.709
# BSV 73000.0
# ORBS 54.96
# TFUEL 74.42
# VALOR 385.8
# CON 13.3
# ANKR 38.66
# MIX 5.669
# CRO 172.9
# FX 348.7
# CHR 255.5
# MBL 6.556
# MXC 100.1
# FCT2 78.67
# TRV 9.898
# DAD 77.0
# WOM 66.68
# SOC 7.298
# BOA 65.89
# MEV 20.55
# SXP 523.0
# COS 9.342
# EL 4.02
# BASIC 2.632
# HIVE 610.5
# XPR 3.914
# VRA 6.755
# FIT 1.369
# EGG 12.85
# BORA 410.3
# ARPA 47.86
# CTC 484.3
# APM 21.5
# CKB 5.485
# AERGO 171.6
# ANW 15.02
# CENNZ 58.52
# EVZ 43.35
# CYCLUB 8.275
# SRM 1327.0
# QTCON 2.193
# UNI 9255.0
# ...

# %%
detail = pybithumb.get_market_detail("BTC")
print(detail)
# Out:
# (29813000.0, 29885000.0, 29738000.0, 29798000.0, 72.2284533)

# %% [markdown]
# //시가//고가//저가//종가//거래량

# %%
detail[2]
# Out:
# 29738000.0

# %%
orderbook = pybithumb.get_orderbook("BTC")
print(orderbook)
for k in orderbook:
    print(k)
# Out:
# {'timestamp': '1658417086600', 'payment_currency': 'KRW', 'order_currency': 'BTC', 'bids': [{'price': 29763000.0, 'quantity': 0.0068}, {'price': 29758000.0, 'quantity': 0.01}, {'price': 29753000.0, 'quantity': 0.1063}, {'price': 29750000.0, 'quantity': 0.0039}, {'price': 29749000.0, 'quantity': 0.6716}], 'asks': [{'price': 29767000.0, 'quantity': 0.3713}, {'price': 29768000.0, 'quantity': 0.0793}, {'price': 29769000.0, 'quantity': 0.0379}, {'price': 29770000.0, 'quantity': 0.4019}, {'price': 29771000.0, 'quantity': 0.0572}]}
# timestamp
# payment_currency
# order_currency
# bids
# asks

# %%
import datetime
ms = int(orderbook["timestamp"])
dt = datetime.datetime.fromtimestamp(ms/1000)
print(dt)
# Out:
# 2022-07-22 00:24:46.600000

# %%
bids = orderbook['bids']
asks = orderbook['asks']
print(bids)
print("----------------")
print(asks)
# Out:
# [{'price': 29763000.0, 'quantity': 0.0068}, {'price': 29758000.0, 'quantity': 0.01}, {'price': 29753000.0, 'quantity': 0.1063}, {'price': 29750000.0, 'quantity': 0.0039}, {'price': 29749000.0, 'quantity': 0.6716}]
# ----------------
# [{'price': 29767000.0, 'quantity': 0.3713}, {'price': 29768000.0, 'quantity': 0.0793}, {'price': 29769000.0, 'quantity': 0.0379}, {'price': 29770000.0, 'quantity': 0.4019}, {'price': 29771000.0, 'quantity': 0.0572}]

# %%
type(bids)
# Out:
# list

# %%
for i in asks:
    print(i)
    
print("------------")

for i in bids:
    print(i)
# Out:
# {'price': 29767000.0, 'quantity': 0.3713}
# {'price': 29768000.0, 'quantity': 0.0793}
# {'price': 29769000.0, 'quantity': 0.0379}
# {'price': 29770000.0, 'quantity': 0.4019}
# {'price': 29771000.0, 'quantity': 0.0572}
# ------------
# {'price': 29763000.0, 'quantity': 0.0068}
# {'price': 29758000.0, 'quantity': 0.01}
# {'price': 29753000.0, 'quantity': 0.1063}
# {'price': 29750000.0, 'quantity': 0.0039}
# {'price': 29749000.0, 'quantity': 0.6716}

# %%
for i in bids:
    price = i['price']
    quant = i['quantity']
    print("매수호가 :", price,"  매수잔량 :",quant)
# Out:
# 매수호가 : 29763000.0   매수잔량 : 0.0068
# 매수호가 : 29758000.0   매수잔량 : 0.01
# 매수호가 : 29753000.0   매수잔량 : 0.1063
# 매수호가 : 29750000.0   매수잔량 : 0.0039
# 매수호가 : 29749000.0   매수잔량 : 0.6716

# %%
all = pybithumb.get_current_price("ALL")
# for k,v in all.items():
#     print(k,v)
#     print()

# %%
type(all)
# Out:
# dict

# %%
for i in all.get("BTC").keys():
    print(i, ":", all.get("BTC").get(i))
# Out:
# opening_price : 29813000
# closing_price : 29782000
# min_price : 29738000
# max_price : 29885000
# units_traded : 80.2059533
# acc_trade_value : 2391249336.5135
# prev_closing_price : 29812000
# units_traded_24H : 6934.84663882
# acc_trade_value_24H : 211357356622.0989
# fluctate_24H : -1848000
# fluctate_rate_24H : -5.84

# %%
print(all.get("BTC"))
# Out:
# {'opening_price': '29813000', 'closing_price': '29782000', 'min_price': '29738000', 'max_price': '29885000', 'units_traded': '80.2059533', 'acc_trade_value': '2391249336.5135', 'prev_closing_price': '29812000', 'units_traded_24H': '6934.84663882', 'acc_trade_value_24H': '211357356622.0989', 'fluctate_24H': '-1848000', 'fluctate_rate_24H': '-5.84'}

# %%
type(all)
# Out:
# dict

# %%
def compare(now,first,second,third):
    now_list

# %%
lets_see = {}

first = -100
second = -200
third = -300

now_up = []
now_up.append(first)
now_up.append(second)
now_up.append(third)

# %%
lets_see = {}
first = -100
second = -200
third = -300
now_up.append(first).append(second).append(third)



for ticker, data in all.items():
    print(ticker, data['closing_price'], "last_night :",data['prev_closing_price'], "변동률 :",data['fluctate_rate_24H'])
    if data['fluctate_rate_24H']> first:
# Out:
# BTC 29782000 last_night : 29812000 변동률 : -5.84
# 29805000.0
# ETH 1986000 last_night : 1981000 변동률 : -5.11
# 1992000.0
# ETC 31770 last_night : 32080 변동률 : -4.11
# 31880.0
# XRP 464.7 last_night : 463.6 변동률 : -5.74
# 465.8
# BCH 161100 last_night : 160400 변동률 : -5.24
# 161000.0
# QTUM 4013 last_night : 3998 변동률 : -6.91
# 4013.0
# BTG 24360 last_night : 24360 변동률 : -6.88
# 24360.0
# EOS 1349 last_night : 1351 변동률 : -6.32
# 1349.0
# ICX 379.6 last_night : 377.3 변동률 : -7.37
# 379.6
# TRX 88.86 last_night : 89 변동률 : -2.02
# 88.97
# ELF 230.8 last_night : 231.1 변동률 : -7.23
# 230.8
# OMG 2474 last_night : 2461 변동률 : -7.20
# 2474.0
# KNC 1857 last_night : 1848 변동률 : -7.06
# 1857.0
# GLM 324.8 last_night : 321.6 변동률 : -4.5
# 323.5
# ZIL 53.17 last_night : 53.23 변동률 : -9.03
# 53.17
# WAXP 133.8 last_night : 133.8 변동률 : -5.58
# 133.8
# POWR 315 last_night : 313.6 변동률 : -7.27
# 314.1
# LRC 552.5 last_night : 551.4 변동률 : -7.64
# 553.2
# STEEM 317 last_night : 316.7 변동률 : -6.54
# 318.2
# ...

# %%
try:
    fuck = all.get("fuck").split("45")
except:
    print("fuck you bitch!")
# Out:
# fuck you bitch!

# %%
eth_get_ohlcv = pybithumb.get_ohlcv("ETH")
print(eth_get_ohlcv)
# Out:
#                           open       high        low      close        volume
# time
# 2016-09-29 00:00:00    14700.0    14800.0    14500.0    14500.0     14.467544
# 2016-09-30 00:00:00    14500.0    14900.0    14500.0    14900.0    204.660008
# 2016-10-01 00:00:00    14900.0    14900.0    14500.0    14500.0    946.095100
# 2016-10-02 00:00:00    14600.0    14600.0    14600.0    14600.0      0.193000
# 2016-10-03 00:00:00    14700.0    14700.0    14600.0    14600.0      3.547600
# ...                        ...        ...        ...        ...           ...
# 2021-07-07 00:00:00  2685000.0  2792000.0  2661000.0  2742000.0  33440.562584
# 2021-07-08 00:00:00  2744000.0  2767000.0  2521000.0  2567000.0  51720.516148
# 2021-07-09 00:00:00  2568000.0  2590000.0  2418000.0  2570000.0  48421.028853
# 2021-07-10 00:00:00  2571000.0  2579000.0  2471000.0  2493000.0  27459.327000
# 2021-07-11 14:00:00  2495000.0  2544000.0  2454000.0  2476000.0  13852.007060
#
# [1744 rows x 5 columns]

# %%
eth_get_ohlc= pybithumb.get_ohlc("ETH")
print(eth_get_ohlc)
# Out:
# {'ETH': (2495000.0, 2544000.0, 2454000.0, 2475000.0)}

# %% [markdown]
# //시가//고가//저가//종가//거래량

# %%
btc_get_ohlcv = pybithumb.get_ohlcv("BTC")
print(btc_get_ohlcv)
# Out:
#                            open        high         low       close  \
# time
# 2013-12-27 00:00:00    737000.0    755000.0    737000.0    755000.0
# 2013-12-28 00:00:00    750000.0    750000.0    750000.0    750000.0
# 2013-12-29 00:00:00    750000.0    750000.0    728000.0    739000.0
# 2013-12-30 00:00:00    740000.0    772000.0    740000.0    768000.0
# 2013-12-31 00:00:00    768000.0    800000.0    763000.0    768000.0
# ...                         ...         ...         ...         ...
# 2021-07-07 00:00:00  39775000.0  40680000.0  39235000.0  40319000.0
# 2021-07-08 00:00:00  40326000.0  40514000.0  38120000.0  38975000.0
# 2021-07-09 00:00:00  38983000.0  39635000.0  38160000.0  39486000.0
# 2021-07-10 00:00:00  39486000.0  40250000.0  39217000.0  39918000.0
# 2021-07-11 14:00:00  39918000.0  40258000.0  39160000.0  39561000.0
#
#                           volume
# time
# 2013-12-27 00:00:00     3.780000
# 2013-12-28 00:00:00    12.000000
# 2013-12-29 00:00:00    19.058000
# ...

# %%
type(eth_get_ohlcv)
# Out:
# pandas.core.frame.DataFrame

# %%
eth_close = eth_get_ohlcv['close']
print(eth_close)
# Out:
# time
# 2016-09-29 00:00:00      14500.0
# 2016-09-30 00:00:00      14900.0
# 2016-10-01 00:00:00      14500.0
# 2016-10-02 00:00:00      14600.0
# 2016-10-03 00:00:00      14600.0
#                          ...
# 2021-07-07 00:00:00    2742000.0
# 2021-07-08 00:00:00    2567000.0
# 2021-07-09 00:00:00    2570000.0
# 2021-07-10 00:00:00    2493000.0
# 2021-07-11 14:00:00    2476000.0
# Name: close, Length: 1744, dtype: float64

# %%
high = 0
low = 999999999999
for i in eth_close:
    if i>high:
        high = i
    if i<low:
        low = i
    
print("high :",high)
print("low :",low)
# Out:
# high : 5294000.0
# low : 8150.0

# %%
window = eth_close.rolling(5)
print(window)
print("fuck u bitch!")
print(type(window))
mean5 = window.mean()

print("fuck u bitch!")
print(mean5)
print("fuck u bitch!")
print(type(mean5))
# Out:
# Rolling [window=5,center=False,axis=0]
# fuck u bitch!
# <class 'pandas.core.window.Rolling'>
# fuck u bitch!
# time
# 2016-09-29 00:00:00          NaN
# 2016-09-30 00:00:00          NaN
# 2016-10-01 00:00:00          NaN
# 2016-10-02 00:00:00          NaN
# 2016-10-03 00:00:00      14620.0
#                          ...
# 2021-07-07 00:00:00    2663800.0
# 2021-07-08 00:00:00    2658600.0
# 2021-07-09 00:00:00    2633800.0
# 2021-07-10 00:00:00    2611400.0
# 2021-07-11 14:00:00    2569600.0
# Name: close, Length: 1744, dtype: float64
# fuck u bitch!
# <class 'pandas.core.series.Series'>

# %%
mean5[-1]
# Out:
# 2569600.0

# %%
eth_close[-1]
# Out:
# 2476000.0

# %%
current_eth_price = pybithumb.get_current_price("ETH")
if current_eth_price<mean5[-2]:
    print("하락!!!!!")
elif mean5[-1]/current_eth_price > 1.05:
    print("상승!!!!")
else:
    print("보합!!!!!")
# Out:
# 하락!!!!!

# %%
print(current_eth_price)
# Out:
# 2475000.0

# %%
def up_down_market(ticker):
    past = pybithumb.get_ohlcv(ticker)
    m5 = past['close'].rolling(5).mean()
    current_p = pybithumb.get_current_price(ticker)
    last_mean5 = m5[-2]
    print(ticker,"current_price :",current_p)
    print("지난 5일",ticker,"평균 :",last_mean5)
    if current_p > last_mean5:
        return True
    else:
        return False

# %%
up_down = up_down_market("ETH")
if up_down:
    print("떡상 가즈아!!!!!")
else:
    print("돔황챠!!!!!")
# Out:
# ETH current_price : 2468000.0
# 지난 5일 ETH 평균 : 2611400.0
# 돔황챠!!!!!

# %%
tickers = pybithumb.get_tickers()
up_count = 0
down_count = 0
for ticker in tickers:
    up_down = up_down_market(ticker)
    if up_down:
        print(ticker,"떡상 가즈아!!!!!")
        up_count+=1
    else:
        print(ticker,"돔황챠!!!!!")
        down_count+=1

print("떡상 코인 수 :",up_count)
print("떡락 코인 수 :",down_count)
# Out:
# BTC current_price : 39469000.0
# 지난 5일 BTC 평균 : 39701400.0
# BTC 돔황챠!!!!!
# ETH current_price : 2469000.0
# 지난 5일 ETH 평균 : 2611400.0
# ETH 돔황챠!!!!!
# LTC current_price : 156900.0
# 지난 5일 LTC 평균 : 159200.0
# LTC 돔황챠!!!!!
# ETC current_price : 57300.0
# 지난 5일 ETC 평균 : 60920.0
# ETC 돔황챠!!!!!
# XRP current_price : 730.0
# 지난 5일 XRP 평균 : 754.9800000000001
# XRP 돔황챠!!!!!
# BCH current_price : 579000.0
# 지난 5일 BCH 평균 : 594400.0
# BCH 돔황챠!!!!!
# QTUM current_price : 7650.0
# 지난 5일 QTUM 평균 : 8018.0
# QTUM 돔황챠!!!!!
# BTG current_price : 50950.0
# 지난 5일 BTG 평균 : 54050.0
# BTG 돔황챠!!!!!
# EOS current_price : 4553.0
# 지난 5일 EOS 평균 : 4577.6
# EOS 돔황챠!!!!!
# ICX current_price : 1050.0
# 지난 5일 ICX 평균 : 1087.8
# ICX 돔황챠!!!!!
# TRX current_price : 71.82
# 지난 5일 TRX 평균 : 74.17199999999987
# TRX 돔황챠!!!!!
# ELF current_price : 232.1
# 지난 5일 ELF 평균 : 242.89999999999978
# ELF 돔황챠!!!!!
# OMG current_price : 4836.0
# 지난 5일 OMG 평균 : 5051.4
# OMG 돔황챠!!!!!
# KNC current_price : 1748.0
# 지난 5일 KNC 평균 : 1859.6
# ...

# %%
def get_target_price(ticker):
    df = pybithumb.get_ohlcv(ticker)
    yesterday = df.iloc[-2]

    today_open = yesterday['close']
    yesterday_high = yesterday['high']
    yesterday_low = yesterday['low']
    target = today_open + (yesterday_high - yesterday_low) * 0.5
    return target

# %%
import datetime
dt = datetime.datetime(2021,7,11)
print(dt)
print(dt.year,dt.month,dt.day)
# Out:
# 2021-07-11 00:00:00
# 2021 7 11

# %%
now = datetime.datetime.now()
print(now)
# Out:
# 2021-07-11 17:19:09.833676

# %%
print(now==dt)
print(now>dt)
# Out:
# False
# True

# %%
now = datetime.datetime.now()
mid = datetime.datetime(now.year, now.month, now.day) + datetime.timedelta(1)
print(now)
print(mid)
# Out:
# 2021-07-11 17:39:59.011691
# 2021-07-12 00:00:00

# %%
now>mid
# Out:
# False

# %%
now<mid
# Out:
# True

# %%
def get_target_price(ticker):
    df = pybithumb.get_ohlcv(ticker)
    yesterday = df.iloc[-2]
    today_open = yesterday['close']
    yesterday_high = yesterday['high']
    yesterday_low = yesterday['low']
    target = today_open + (yesterday_high - yesterday_low) * 0.5
    return target

now = datetime.datetime.now()
mid = datetime.datetime(now.year, now.month, now.day) + datetime.timedelta(1)
target_price = get_target_price("BTC")
print("target price :",target_price)

while True:
    now = datetime.datetime.now()
    if mid < now < mid + datetime.timedelta(seconds=10) : 
        target_price = get_target_price("BTC")
        mid = datetime.datetime(now.year, now.month, now.day) + datetime.timedelta(1)
    current_price = pybithumb.get_current_price("BTC")
    print(current_price)
    time.sleep(1)
# Out:
# target price : 40434500.0
# 39734000.0
# 39734000.0
# 39734000.0
# 39734000.0
# 39734000.0
# 39734000.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-113-07bddfe1057f> in <module>
#      20     current_price = pybithumb.get_current_price("BTC")
#      21     print(current_price)
# ---> 22     time.sleep(1)
#
# KeyboardInterrupt:

# %%
eth_df = pybithumb.get_ohlcv("ETH")
eth_df.to_excel('eth.xlsx')

# %%
fee = 0.0032
eth_df['range'] = (eth_df['high']-eth_df['low'])*0.5
eth_df['target'] = eth_df['open']+eth_df['range'].shift(1)
eth_df['ror'] = np.where(eth_df['high'] > eth_df['target'], 
                  eth_df['close'] / eth_df['target'] - fee,
                  1)
                        
eth_df.to_excel('eth.xlsx')

print(eth_df['total_roi'][-1])
# Out:
# 1.0

# %%
fee = 0.0032

# %%
import numpy as np
from pandas import DataFrame

# %%
ror = eth_df['ror'].cumprod()[-1]
print(ror)
# Out:
# 14.041102215960183

# %%
for ticker in tickers:
    coin_df = pybithumb.get_ohlcv(ticker)
    coin_df['range'] = (coin_df['high']-coin_df['low'])*0.5
    coin_df['target'] = coin_df['open']+coin_df['range'].shift(1)
    coin_df['ror'] = np.where(coin_df['high'] > coin_df['target'], 
                  coin_df['close'] / coin_df['target'] - fee,
                  1)
    print(ticker, ":", coin_df['ror'].cumprod()[-2], "days : ",len(coin_df))
# Out:
# BTC : 1.6835346723917046 days :  2686
# ETH : 16.023709020770866 days :  1766
# LTC : 0.18217125923638136 days :  1554
# ETC : 0.0641858847998121 days :  1539
# XRP : 5.988778319067634 days :  1526
# BCH : 0.6543428630663866 days :  1461
# QTUM : 0.7328810391067291 days :  1384
# BTG : 0.017094897686343598 days :  1350
# EOS : 0.07975644742242997 days :  1331
# ICX : 0.07671710454383229 days :  1230
# TRX : 0.3047957427162066 days :  1216
# ELF : 0.0013376927480120238 days :  1210
# OMG : 0.10080790218146367 days :  1196
# KNC : 0.0553329624519113 days :  1196
# GLM : 0.001191102552130009 days :  1189
# ZIL : 0.39029355054151194 days :  1182
# WAXP : 0.0016764933168202905 days :  1176
# POWR : 0.004211063247450529 days :  1176
# LRC : 0.0384901681928241 days :  1176
# STEEM : 0.02710057250661713 days :  1168
# STRAX : 0.03896414673770943 days :  1160
# ZRX : 0.02003256240533756 days :  1162
# REP : 0.009265842525100185 days :  1162
# XEM : 0.014646564141039643 days :  1154
# ...

# %%
tickers = pybithumb.get_tickers()

# %%
fee = 0.0032

# %%
coin_df = pybithumb.get_ohlcv(ticker)

# %%
3764000/15000
# Out:
# 250.93333333333334

# %%
print(coin_df)
# Out:
#                           open       high        low      close        volume
# time
# 2016-09-29 00:00:00    14700.0    14800.0    14500.0    14500.0     14.467544
# 2016-09-30 00:00:00    14500.0    14900.0    14500.0    14900.0    204.660008
# 2016-10-01 00:00:00    14900.0    14900.0    14500.0    14500.0    946.095100
# 2016-10-02 00:00:00    14600.0    14600.0    14600.0    14600.0      0.193000
# 2016-10-03 00:00:00    14700.0    14700.0    14600.0    14600.0      3.547600
# ...                        ...        ...        ...        ...           ...
# 2021-08-13 00:00:00  3551000.0  3767000.0  3501000.0  3732000.0  39633.238395
# 2021-08-14 00:00:00  3732000.0  3868000.0  3698000.0  3813000.0  41513.583134
# 2021-08-15 00:00:00  3813000.0  3837000.0  3663000.0  3688000.0  26271.075684
# 2021-08-16 00:00:00  3687000.0  3869000.0  3657000.0  3731000.0  29452.672909
# 2021-08-17 19:00:00  3731000.0  3780000.0  3630000.0  3770000.0  26479.485756
#
# [1781 rows x 5 columns]

# %%
ticker = "ETH"
now_basic = 0
best_basic = 0
now_simple = 0
best_simple = 0
best_k_simple = 0
best_j_simple = 0
best_k_basic = 0
for k in range(1,100):
    for j in range(1,100):
        coin_df = pybithumb.get_ohlcv(ticker)
        if type(coin_df) != DataFrame:
            while type(coin_df) != DataFrame:
                coin_df = pybithumb.get_ohlcv(ticker)
                time.sleep(0.01) 
                iter_count += 1
                if type(coin_df) == DataFrame:
                    print(iter_count)
                    iter_count = 0
        coin_df['range'] = (coin_df['high']-coin_df['low'])*0.01*k
        coin_df['target'] = coin_df['open']+coin_df['range'].shift(1)
        coin_df['target'][0] = coin_df['high'][0]+100
        coin_df['ror'] = np.where((coin_df['high'] > coin_df['target']), 
                          coin_df['close'] / coin_df['target'] - fee,
                          1)
        check = 1+0.01*j
        coin_df['test_ror'] = np.where((coin_df['ror'] != 1) & (coin_df['high']/coin_df['target'] > check), 
                          check - fee,
                          coin_df['ror'])
        print("-----------")
        print("k :",k)
        print("j :",j)
        print("basic : "+ticker, ":", coin_df['ror'].cumprod()[-2], "days : ",len(coin_df))
        print("simpl : "+ticker, ":", coin_df['test_ror'].cumprod()[-2], "days : ",len(coin_df))
        print("***********")
        now_basic = coin_df['ror'].cumprod()[-2]
        now_simple = coin_df['test_ror'].cumprod()[-2]
        if now_basic > best_basic:
            best_basic = now_basic
            best_k_basic = k
        if now_simple > best_simple:
            best_simple = now_simple
            best_k_simple = k
            best_j_simple = j
            
print("%%%%%%%%%%money is coming%%%%%%%%%%%%%%%%")
print("best_simple : ",best_simple)
print("best_k_simple : ", best_k_simple)
print("best_j_simple : ", best_j_simple)
print("best_basic :",best_basic)
print("best_k_basic : ",best_k_basic)
print("%%%%%%%%%%ready to be rich%%%%%%%%%%%%%%%%")
# Out:
# -----------
# k : 1
# j : 1
# basic : ETH : 1.6000294247545659 days :  1781
# simpl : ETH : 0.002221030356458139 days :  1781
# ***********
# -----------
# k : 1
# j : 2
# basic : ETH : 1.6000294247545659 days :  1781
# simpl : ETH : 0.007780931415725421 days :  1781
# ***********
# -----------
# k : 1
# j : 3
# basic : ETH : 1.6000294247545659 days :  1781
# simpl : ETH : 0.01117595683638898 days :  1781
# ***********
# -----------
# k : 1
# j : 4
# basic : ETH : 1.6000294247545659 days :  1781
# simpl : ETH : 0.019055859163893494 days :  1781
# ***********
# -----------
# k : 1
# j : 5
# basic : ETH : 1.6000294247545659 days :  1781
# simpl : ETH : 0.029899697488541967 days :  1781
# ***********
# -----------
# k : 1
# j : 6
# basic : ETH : 1.6000294247545659 days :  1781
# simpl : ETH : 0.07217744193763419 days :  1781
# ***********
# -----------
# k : 1
# j : 7
# basic : ETH : 1.6000294247545659 days :  1781
# simpl : ETH : 0.16676899177009807 days :  1781
# ***********
# ...

# %%
basic= 0
simple = 0
for ticker in tickers:
    coin_df = pybithumb.get_ohlcv(ticker)
    if type(coin_df) != DataFrame:
        while type(coin_df) != DataFrame:
            coin_df = pybithumb.get_ohlcv(ticker)
            time.sleep(0.01) 
            iter_count += 1
            if type(coin_df) == DataFrame:
                print(iter_count)
                iter_count = 0
    coin_df['range'] = (coin_df['high']-coin_df['low'])*0.55
    coin_df['target'] = coin_df['open']+coin_df['range'].shift(1)
    coin_df['target'][0] = coin_df['high'][0]+100
    coin_df['ror'] = np.where((coin_df['high'] > coin_df['target']), 
                      coin_df['close'] / coin_df['target'] - fee,
                      1)
    check = 1.10
    coin_df['test_ror'] = np.where((coin_df['ror'] != 1) & (coin_df['high']/coin_df['target'] > check), 
                      check - fee,
                      coin_df['ror'])
    print("basic : "+ticker, ":", coin_df['ror'].cumprod()[-2], "days : ",len(coin_df))
    if  coin_df['ror'].cumprod()[-2] > 1:
        basic+=1
    print("simpl : "+ticker, ":", coin_df['test_ror'].cumprod()[-2], "days : ",len(coin_df))
    if  coin_df['test_ror'].cumprod()[-2] > 1:
        simple+=1
        
print(basic)
print(simple)
# Out:
# basic : BTC : 3.6278948761927974 days :  2701
# simpl : BTC : 8.512093410829504 days :  2701
# basic : ETH : 9.606439260342096 days :  1781
# simpl : ETH : 25.86523663588181 days :  1781
# basic : LTC : 0.16165910944526954 days :  1569
# simpl : LTC : 0.4413639047633235 days :  1569
# basic : ETC : 0.08454367816818124 days :  1554
# simpl : ETC : 0.10819056793133099 days :  1554
# basic : XRP : 13.183019590996333 days :  1541
# simpl : XRP : 2.4074208872869884 days :  1541
# basic : BCH : 1.0985764709586467 days :  1476
# simpl : BCH : 1.1073946635720868 days :  1476
# basic : QTUM : 1.0778366971355389 days :  1399
# simpl : QTUM : 2.415181502509504 days :  1399
# basic : BTG : 0.028289476288175318 days :  1365
# simpl : BTG : 0.04793362563650999 days :  1365
# basic : EOS : 0.08713875752645514 days :  1346
# simpl : EOS : 0.1712059218749044 days :  1346
# basic : ICX : 0.14519066488378093 days :  1245
# simpl : ICX : 0.6817058300035311 days :  1245
# ...

# %%
count_test = 0
count_ror = 0
for ticker in tickers:
    coin_df = pybithumb.get_ohlcv(ticker)
    coin_df['range'] = (coin_df['high']-coin_df['low'])*0.5
    coin_df['target'] = coin_df['open']+coin_df['range'].shift(1)
    coin_df['target'][0] = coin_df['high'][0]+100

    coin_df['ror'] = np.where((coin_df['high'] > coin_df['target']), 
                      coin_df['close'] / coin_df['target'] - fee,
                      1)
    check = 1.10
    coin_df['test_ror'] = np.where((coin_df['ror'] != 1) & (coin_df['high']/coin_df['target'] > check), 
                      check - fee,
                      coin_df['ror'])
    print(ticker, "_ror :", coin_df['ror'].cumprod()[-2], "days : ",len(coin_df))
    print(ticker, "_test_ror :", coin_df['test_ror'].cumprod()[-2], "days : ",len(coin_df))
    if coin_df['ror'].cumprod()[-2] > 1:
        count_ror +=1
    if coin_df['test_ror'].cumprod()[-2] > 1:
        count_test +=1
print('total :',len(tickers))
print(count_test)
print(count_ror)
# Out:
# BTC _ror : 1.6835346723917046 days :  2686
# BTC _test_ror : 3.9202166112602526 days :  2686
# ETH _ror : 16.023709020770866 days :  1766
# ETH _test_ror : 40.89807668224188 days :  1766
# LTC _ror : 0.18217125923638136 days :  1554
# LTC _test_ror : 0.5009200723269663 days :  1554
# ETC _ror : 0.0641858847998121 days :  1539
# ETC _test_ror : 0.1458984555202733 days :  1539
# XRP _ror : 5.988778319067634 days :  1526
# XRP _test_ror : 0.9735211158245315 days :  1526
# BCH _ror : 0.6543428630663866 days :  1461
# BCH _test_ror : 0.5167365763802306 days :  1461
# QTUM _ror : 0.7328810391067291 days :  1384
# QTUM _test_ror : 1.5132201532967275 days :  1384
# BTG _ror : 0.017094897686343598 days :  1350
# BTG _test_ror : 0.025236215911476203 days :  1350
# EOS _ror : 0.07975644742242997 days :  1331
# EOS _test_ror : 0.15495053711919102 days :  1331
# ICX _ror : 0.07671710454383229 days :  1230
# ICX _test_ror : 0.26821634826199525 days :  1230
# ...

# %%
for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
if type(coin_df) == DataFrame:
    print("fuck!")
# Out:
# fuck!

# %%
type(coin_df)
# Out:
# pandas.core.frame.DataFrame

# %%
coin_df = pybithumb.get_ohlcv("ETH")

# %%
type(coin_df)
while type(coin_df) != DataFrame:
    print("fuck")
    coin_df = pybithumb.get_ohlcv("ETH")
print(type(coin_df))
# Out:
# fuck
# <class 'pandas.core.frame.DataFrame'>

# %%
tickers = pybithumb.get_tickers()
most_test = 0
most_ror = 0
most_sell_now = 0
most_test_k = 0
most_ror_k = 0
iter_coint = 0
print('total :',len(tickers))
for j in range(28,100):
    for i in range(1,100):
        count_test = 0
        count_ror = 0
        time.sleep(0.01)
        for ticker in tickers:
            coin_df = pybithumb.get_ohlcv(ticker)
            if type(coin_df) != DataFrame:
                while type(coin_df) != DataFrame:
                    coin_df = pybithumb.get_ohlcv(ticker)
                    time.sleep(0.01) 
                    iter_count += 1
                    if type(coin_df) == DataFrame:
                        print(iter_count)
                        iter_count = 0
            coin_df['range'] = (coin_df['high']-coin_df['low'])*i*0.01
            coin_df['target'] = coin_df['open']+coin_df['range'].shift(1)
            coin_df['target'][0] = coin_df['high'][0]+100
            coin_df['ror'] = np.where((coin_df['high'] > coin_df['target']), 
                              coin_df['close'] / coin_df['target'] - fee,
                              1)
            check = 1+j*0.01
            coin_df['test_ror'] = np.where((coin_df['ror'] != 1) & (coin_df['high']/coin_df['target'] > check), 
                              check - fee,
                              coin_df['ror'])
#             print(ticker, "_ror :", coin_df['ror'].cumprod()[-2], "days : ",len(coin_df))
#             print(ticker, "_test_ror :", coin_df['test_ror'].cumprod()[-2], "days : ",len(coin_df))
            if coin_df['ror'].cumprod()[-2] > 1:
                count_ror +=1
            if coin_df['test_ror'].cumprod()[-2] > 1:
                count_test +=1
        if count_test > most_test:
            most_test = count_test
            most_test_k = i*0.01
            most_sell_now = 1+j*0.01
        if count_ror > most_ror:
            most_ror = count_ror
            most_ror_k = i*0.01
        print("%%%%%%%%%%%")
        print(count_test)
        print(count_ror)
        print("k : ", i*0.01)
        print("몇 퍼에서 빼 : ", j*0.01)
        print("%%%%%%%%%%%")
        
print('most_test : ',most_test)
print('most_sell_now : ', most_sell_now)
print('mpst_test_k : ',most_test_k)
print("!@#!@#!@##$%#$%#$%#$%%^&%^&%^&%^&")
print('most_ro₩₩r : ',most_ror)
print('most_ror_k : ',most_ror_k)
# Out:
# total : 177
# %%%%%%%%%%%
# 93
# 46
# k :  0.01
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 90
# 42
# k :  0.02
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 86
# 41
# k :  0.03
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 80
# 37
# k :  0.04
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 79
# 34
# k :  0.05
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 77
# 34
# k :  0.06
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 74
# 33
# k :  0.07
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 71
# 30
# k :  0.08
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 66
# 30
# k :  0.09
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 64
# 27
# k :  0.1
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 62
# 27
# k :  0.11
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 58
# 24
# k :  0.12
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 57
# 22
# k :  0.13
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 57
# 23
# k :  0.14
# 몇 퍼에서 빼 :  0.28
# %%%%%%%%%%%
# %%%%%%%%%%%
# 58
# 25
# ...

# %%
check = open('should_check.txt')
check_ori = check.readlines()
most_k = 0
now_k = 0
most_test_k = 0
now_test_k = 0
most_sell_now = 0
now_sell_now = 0
most_test = 0
now_test = 0
most_ror = 0
now_ror = 0
information = False
line = -1
for i in check_ori:
    if information == False:
        if '%%%%%%%%%%%' in i:
            information = True
            line+=1
    else:
        if '%%%%%%%%%%%' in i:
            information = False
            line = -1
        elif information and line ==0:
            now_test = float(i.replace("\n",""))
            if now_test> most_test:
                most_test = now_test
            line +=1
        elif information and line ==1:
            now_ror = float(i.replace("\n",""))
            if now_ror>most_ror:
                most_ror = now_ror
            line +=1

print(most_test)
print(most_ror)
# Out:
# 124.0
# 46.0

# %%
if type(coin_df) != None:
    print("fuck!")
# Out:
# fuck!

# %%
import asyncio

# %%
async def make_americano():
    print("아메리카노 시작")
    await asyncio.sleep(3)
    print("아메리카노 끝")
    
async def make_latte():
    print("라떼 시작")
    await asyncio.sleep(5)
    print("라떼 끝")
    
async def main():
    coco1 = make_americano()
    coco2 = make_latte()
    await asyncio.gather(coco1,coco2)
    
print("카페 영업 시작!")
asyncio.run(main())
print("카페 영업 종료!")
# Out:
# 카페 영업 시작!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-150-9ed4045fdae2> in <module>
#      15
#      16 print("카페 영업 시작!")
# ---> 17 asyncio.run(main())
#      18 print("카페 영업 종료!")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/asyncio/runners.py in run(main, debug)
#      32     if events._get_running_loop() is not None:
#      33         raise RuntimeError(
# ---> 34             "asyncio.run() cannot be called from a running event loop")
#      35
#      36     if not coroutines.iscoroutine(main):
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
import asyncio 

async def make_americano():
    print("Americano Start")
    await asyncio.sleep(3)
    print("Americano End")

async def make_latte():
    print("Latte Start")
    await asyncio.sleep(5)
    print("Latte End")

async def main():
    coro1 = make_americano()
    coro2 = make_latte()
    await asyncio.gather(
        coro1, 
        coro2
    )

# %%
print("Main Start")
asyncio.run(main())
print("Main End")
# Out:
# Main Start
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-153-ba94e444b60d> in <module>
#       1 print("Main Start")
# ----> 2 asyncio.run(main())
#       3 print("Main End")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/asyncio/runners.py in run(main, debug)
#      32     if events._get_running_loop() is not None:
#      33         raise RuntimeError(
# ---> 34             "asyncio.run() cannot be called from a running event loop")
#      35
#      36     if not coroutines.iscoroutine(main):
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
let from = (new Date("2019-12-20")).getTime() / 1000 # convert to seconds since epoch
let to = (new Date("2020-01-20")).getTime() / 1000

let url = `https://api.oilpriceapi.com/v1/prices?by_period[from]=${from}&by_period[to]=${to}`

const headers = {
  'Authorization': 'Token YOUR_API_TOKEN',
  'Content-Type': 'application/json'
}

fetch(url, { headers })
  .then(response => response.json())
  .then(prices => console.log(prices))
# Out:
#   File "/var/folders/mk/vvw0fvgs2n9947bdh48x53xh0000gn/T/ipykernel_97191/2678525085.py", line 1
#     let from = (new Date("2019-12-20")).getTime() / 1000 # convert to seconds since epoch
#            ^
# SyntaxError: invalid syntax

# %%
import requests

# from1 = 1576800000
# to = 1576972800


# let from = (new Date("2019-12-20")).getTime() / 1000 # convert to seconds since epoch
# let to = (new Date("2020-01-20")).getTime() / 1000

# let url = `https://api.oilpriceapi.com/v1/prices?by_period[from]=${from}&by_period[to]=${to}`
    
    
url = 'https://api.oilpriceapi.com/v1/prices?by_period[1576800000]=1576800000&by_period[1576972800]=1576972800'
headers = {
  'Authorization': 'Token e29d116154709c910b173e052bc831bc',
  'Content-Type': 'application/json'
}

response = requests.get(url = url, headers = headers)
data = response.json()
print(data)
# Out:
# {'status': 'success', 'data': {'prices': [{'price': 84.16, 'formatted': '$84.16', 'currency': 'USD', 'code': 'BRENT_CRUDE_USD', 'created_at': '2018-10-07T13:50:07.253Z', 'type': 'spot_price'}, {'price': 84.16, 'formatted': '$84.16', 'currency': 'USD', 'code': 'BRENT_CRUDE_USD', 'created_at': '2018-10-07T14:00:12.236Z', 'type': 'spot_price'}, {'price': 84.16, 'formatted': '$84.16', 'currency': 'USD', 'code': 'BRENT_CRUDE_USD', 'created_at': '2018-10-07T14:12:32.888Z', 'type': 'spot_price'}, {'price': 84.16, 'formatted': '$84.16', 'currency': 'USD', 'code': 'BRENT_CRUDE_USD', 'created_at': '2018-10-07T14:20:07.090Z', 'type': 'spot_price'}, {'price': 84.16, 'formatted': '$84.16', 'currency': 'USD', 'code': 'BRENT_CRUDE_USD', 'created_at': '2018-10-07T14:30:07.068Z', 'type': 'spot_price'}, {'price': 84.16, 'formatted': '$84.16', 'currency': 'USD', 'code': 'BRENT_CRUDE_USD', 'created_at': '2018-10-07T14:40:07.286Z', 'type': 'spot_price'}, {'price': 84.16, 'formatted': '$84.16', 'currency'
# ...
